# %% [markdown]
# ## Train pi0.5

# %%
from datetime import datetime
import os
from dotenv import load_dotenv
load_dotenv()  # loads HF_TOKEN and WANDB_API_KEY from .env
## Set NCCL environment variables for distributed training in GCP G4 
## single instance, multi-GPU setup. Adjust the interface name (e.g., "ens3") as needed for your specific instance type.
os.environ.pop("NCCL_NET", None) # on single instance, multi-GPU setup, NCCL_NET should not be set to "IB" or "TCP"
os.environ["NCCL_SOCKET_IFNAME"] = "ens3" # Adjust "ens3" to the correct network interface for your GCP instance (e.g., "ens4", "eth0", etc.)
os.environ["NCCL_P2P_LEVEL"] = "PHB" # Set the P2P level to "PHB" (PCIe Host Bridge) for optimal GPU communication on a single instance
os.environ["TOKENIZERS_PARALLELISM"] = "false" # Disable parallelism in tokenizers to avoid potential issues with multiprocessing
import warnings
warnings.filterwarnings("ignore")

# %%
# !rm -rf ckpt #remove checkpoint directory if it already exists to avoid conflicts with previous runs
# !rm -rf logs #remove logs directory if it already exists to avoid conflicts with previous runs

# %%
import configparser
config = configparser.ConfigParser()
config.read("experiment.cfg")
exp = config["experiment"]

DATASET_ROOT = exp["DATASET_ROOT"]
DATASET_REPO = exp["DATASET_REPO"]
POLICY_REPO = exp["POLICY_REPO"]
OUTPUT_DIR = exp["OUTPUT_DIR"]
JOB_NAME = exp["JOB_NAME"] + datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
MAX_TRAIN_STEPS = int(exp["MAX_TRAIN_STEPS"])
CHUNK_SIZE = int(exp["CHUNK_SIZE"])
ACTION_STEPS = int(exp["ACTION_STEPS"])
BATCH_SIZE = int(exp["BATCH_SIZE"])

# %%
#--dataset.root={DATASET_ROOT} \
# !hf download {DATASET_REPO} --repo-type dataset --local-dir {DATASET_ROOT}
# Out:
# Fetching 8 files:   0%|                                   | 0/8 [00:00<?, ?it/s]Downloading 'meta/tasks.parquet' to 'dataset/teleoperation_clr_dataset/.cache/huggingface/download/meta/zpI_TpC7Vh3pdKT0qDPhIBYhxfs=.1536206da1198c18f686b635e6f7ce4733fab0549de88fbf8887eebf91669c5f.incomplete'
# Downloading 'data/chunk-000/file-000.parquet' to 'dataset/teleoperation_clr_dataset/.cache/huggingface/download/data/chunk-000/Rk5xtNxR079Ysk7EiCU6jR-aXfw=.a8820ed5a774e088f0366591bedacb39fc91ba60098630890974519eb9db56ea.incomplete'
# Downloading 'images/observation.wrist_image/episode-000003/frame-000000.png' to 'dataset/teleoperation_clr_dataset/.cache/huggingface/download/images/observation.wrist_image/episode-000003/qju8Nc4mh_HNL5y2qiOVQhRdbHs=.65caeac50eaf4c5e53954f9f1cfba3ec8ec6f0b90936a26baadc3d558e00a884.incomplete'
# Downloading 'meta/episodes/chunk-000/file-000.parquet' to 'dataset/teleoperation_clr_dataset/.cache/huggingface/download/meta/episodes/chunk-000/Rk5xtNxR079Ysk7EiCU6jR-aXfw=.ff73809b153caddcaf7d3487ff9678ff92618f0fc6feb0ef5c54dd6524de966f.incomplete'
# Downloading '.gitattributes' to 'dataset/teleoperation_clr_dataset/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.bed0738c7eeb449bca98b5d2f33c89a1ee56349a.incomplete'
# Downloading 'images/observation.image/episode-000003/frame-000000.png' to 'dataset/teleoperation_clr_dataset/.cache/huggingface/download/images/observation.image/episode-000003/qju8Nc4mh_HNL5y2qiOVQhRdbHs=.9267b9fa2f49151bf5288bfcf6ae5a7751fd3632bde37ee43964239348afd849.incomplete'
#
# meta/tasks.parquet:   0%|                           | 0.00/2.42k [00:00<?, ?B/s]Downloading 'meta/info.json' to 'dataset/teleoperation_clr_dataset/.cache/huggingface/download/meta/c-Q9HGFI0JpMTOZ5pylhXwaYu2U=.e857da34f8df16253d4e819de6a7a0166ed6b3db.incomplete'
#
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:00<?, ?B/s]Downloading 'meta/stats.json' to 'dataset/teleoperation_clr_dataset/.cache/huggingface/download/meta/b96sC8rCl6ISzlk4iRUGFDDYzCg=.73090e4e1a0605fc559eaf02787cda3b4104c13f.incomplete'
#
#
#
# meta/episodes/chunk-000/file-000.parquet:   0%|     | 0.00/68.4k [00:00<?, ?B/s]
#
#
#
# images/observation.wrist_image/episode-0(…):   0%|  | 0.00/22.1k [00:00<?, ?B/s]
#
#
#
#
# images/observation.image/episode-000003/(…):   0%|  | 0.00/21.1k [00:00<?, ?B/s]
#
#
#
#
#
# stats.json: 20.9kB [00:00, 105MB/s][A
# Download complete. Moving file to dataset/teleoperation_clr_dataset/meta/stats.json
#
#
#
#
#
#
# info.json: 3.35kB [00:00, 28.0MB/s]A
# Download complete. Moving file to dataset/teleoperation_clr_dataset/meta/info.json
#
#
#
#
#
#
# .gitattributes: 2.50kB [00:00, 19.0MB/s]A
# Download complete. Moving file to dataset/teleoperation_clr_dataset/.gitattributes
# Fetching 8 files:  12%|███▍                       | 1/8 [00:00<00:03,  2.02it/s]
#
#
#
# images/observation.wrist_image/episode-0(…):   0%|  | 0.00/22.1k [00:00<?, ?B/s]
#
#
# meta/episodes/chunk-000/file-000.parquet:   0%|     | 0.00/68.4k [00:00<?, ?B/s]
# meta/tasks.parquet:   0%|                           | 0.00/2.42k [00:00<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:00<?, ?B/s]
#
#
#
#
# images/observation.image/episode-000003/(…):   0%|  | 0.00/21.1k [00:00<?, ?B/s]
#
#
# meta/episodes/chunk-000/file-000.parquet:   0%|     | 0.00/68.4k [00:00<?, ?B/s]
#
#
#
# images/observation.wrist_image/episode-0(…):   0%|  | 0.00/22.1k [00:00<?, ?B/s]
#
#
#
# meta/episodes/chunk-000/file-000.parquet: 100%|█| 68.4k/68.4k [00:00<00:00, 69.4
# Download complete. Moving file to dataset/teleoperation_clr_dataset/meta/episodes/chunk-000/file-000.parquet
#
#
#
#
#
# images/observation.image/episode-000003/(…):   0%|  | 0.00/21.1k [00:00<?, ?B/s]
#
#
#
#
# images/observation.image/episode-000003/(…): 100%|█| 21.1k/21.1k [00:00<00:00, 2
# Download complete. Moving file to dataset/teleoperation_clr_dataset/images/observation.image/episode-000003/frame-000000.png
#
#
# images/observation.wrist_image/episode-0(…): 100%|█| 22.1k/22.1k [00:01<00:00, 2
# Download complete. Moving file to dataset/teleoperation_clr_dataset/images/observation.wrist_image/episode-000003/frame-000000.png
#
# meta/tasks.parquet: 100%|██████████████████| 2.42k/2.42k [00:01<00:00, 6.54kB/s]
# meta/tasks.parquet: 100%|██████████████████| 2.42k/2.42k [00:01<00:00, 2.25kB/s]
# Download complete. Moving file to dataset/teleoperation_clr_dataset/meta/tasks.parquet
#
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:01<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:01<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:01<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:01<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:01<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:01<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:01<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:01<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:01<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:01<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:01<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:02<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:02<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:02<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:02<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:02<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:02<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:02<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:02<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0%|              | 0.00/97.6M [00:02<?, ?B/s]
#
# data/chunk-000/file-000.parquet:  69%|████▏ | 67.2M/97.6M [00:02<00:00, 159MB/s]
#
# data/chunk-000/file-000.parquet: 100%|█████| 97.6M/97.6M [00:03<00:00, 26.2MB/s]
# Download complete. Moving file to dataset/teleoperation_clr_dataset/data/chunk-000/file-000.parquet
# Fetching 8 files: 100%|███████████████████████████| 8/8 [00:03<00:00,  2.01it/s]
# /mnt/content/Lerobot-MujoCo/dataset/teleoperation_clr_dataset

# %%
# Train the policy pi05 with the specified configuration. The model will be pushed to the Hugging Face Hub under the provided POLICY_REPO name after training.
# !accelerate launch \
--multi_gpu \
--num_machines=1 \
--num_processes=4 \
--mixed_precision=bf16 \
$(which lerobot-train) \
    --dataset.repo_id={DATASET_REPO} \
    --dataset.root={DATASET_ROOT} \
    --policy.type=pi05 \
    --policy.push_to_hub=true \
    --policy.repo_id={POLICY_REPO} \
    --output_dir={OUTPUT_DIR} \
    --job_name={JOB_NAME} \
    --policy.pretrained_path=lerobot/pi05_base \
    --policy.compile_model=false \
    --policy.gradient_checkpointing=true \
    --wandb.enable=true \
    --policy.dtype=bfloat16 \
    --policy.freeze_vision_encoder=false \
    --policy.train_expert_only=false \
    --steps={MAX_TRAIN_STEPS} \
    --log_freq=50 \
    --eval_freq=-1 \
    --policy.device=cuda \
    --policy.chunk_size={CHUNK_SIZE} \
    --policy.n_action_steps={ACTION_STEPS} \
    --batch_size={BATCH_SIZE}
# Out:
# INFO 2026-03-20 01:03:48 ot_train.py:274 {'batch_size': 32,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'gimarchetti/clr-experiment-dataset',
#              'revision': None,
#              'root': './dataset/teleoperation_clr_dataset',
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': -1,
#  'job_name': 'clr-experiment-pi052026-03-20_01-02-38',
#  'log_freq': 50,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.95],
#                'eps': 1e-08,
#                'grad_clip_norm': 1.0,
#                'lr': 2.5e-05,
#                'type': 'adamw',
#                'weight_decay': 0.01},
#  'output_dir': 'ckpt/clr-experiment-pi05',
#  'peft': None,
#  'policy': {'action_expert_variant': 'gemma_300m',
#             'chunk_size': 100,
#             'compile_mode': 'max-autotune',
#             'compile_model': False,
#             'device': 'cuda',
#             'dtype': 'bfloat16',
#             'empty_cameras': 0,
#             'freeze_vision_encoder': False,
#             'gradient_checkpointing': True,
#             'image_resolution': [224, 224],
#             'input_features': {},
#             'license': None,
#             'max_action_dim': 32,
#             'max_period': 4.0,
#             'max_state_dim': 32,
#             'min_period': 0.004,
#             'n_action_steps': 50,
#             'n_obs_steps': 1,
#             'normalization_mapping': {'ACTION': <NormalizationMode.QUANTILES: 'QUANTILES'>,
#                                       'STATE': <NormalizationMode.QUANTILES: 'QUANTILES'>,
#                                       'VISUAL': <NormalizationMode.IDENTITY: 'IDENTITY'>},
#             'num_inference_steps': 10,
#             'optimizer_betas': [0.9, 0.95],
#             'optimizer_eps': 1e-08,
#             'optimizer_grad_clip_norm': 1.0,
#             'optimizer_lr': 2.5e-05,
#             'optimizer_weight_decay': 0.01,
#             'output_features': {},
#             'paligemma_variant': 'gemma_2b',
#             'pretrained_path': 'lerobot/pi05_base',
#             'private': None,
#             'push_to_hub': True,
#             'repo_id': 'gimarchetti/clr-experiment-pi05',
#             'rtc_config': None,
#             'scheduler_decay_lr': 2.5e-06,
#             'scheduler_decay_steps': 30000,
#             'scheduler_warmup_steps': 1000,
#             'tags': None,
#             'time_sampling_beta_alpha': 1.5,
#             'time_sampling_beta_beta': 1.0,
#             'time_sampling_offset': 0.001,
#             'time_sampling_scale': 0.999,
#             'tokenizer_max_length': 200,
#             'train_expert_only': False,
#             'type': 'pi05',
#             'use_amp': False,
#             'use_peft': False},
#  'rabc_epsilon': 1e-06,
#  'rabc_head_mode': 'sparse',
#  'rabc_kappa': 0.01,
#  'rabc_progress_path': None,
#  'rename_map': {},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 20000,
#  'scheduler': {'decay_lr': 2.5e-06,
#                'num_decay_steps': 30000,
#                'num_warmup_steps': 1000,
#                'peak_lr': 2.5e-05,
#                'type': 'cosine_decay_with_warmup'},
#  'seed': 1000,
#  'steps': 400,
#  'tolerance_s': 0.0001,
#  'use_policy_training_preset': True,
#  'use_rabc': False,
#  'wandb': {'disable_artifact': False,
#            'enable': True,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# /home/gimarchetti_google_com/miniconda3/envs/mujoco2/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /home/gimarchetti_google_com/miniconda3/envs/mujoco2/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# INFO 2026-03-20 01:03:50 db_utils.py:102 Logs will be synced with wandb.
# INFO 2026-03-20 01:03:50 db_utils.py:103 Track this run --> https://wandb.ai/gimarchetti-google/lerobot/runs/4tqmzkr6
# INFO 2026-03-20 01:03:50 ot_train.py:294 Creating dataset
# INFO 2026-03-20 01:03:50 ot_train.py:313 Creating policy
# The PI05 model is a direct port of the OpenPI implementation.
# This implementation follows the original OpenPI structure for compatibility.
# Original implementation: https://github.com/Physical-Intelligence/openpi
# The PI05 model is a direct port of the OpenPI implementation.
# This implementation follows the original OpenPI structure for compatibility.
# Original implementation: https://github.com/Physical-Intelligence/openpi
# The PI05 model is a direct port of the OpenPI implementation.
# This implementation follows the original OpenPI structure for compatibility.
# Original implementation: https://github.com/Physical-Intelligence/openpi
# The PI05 model is a direct port of the OpenPI implementation.
# This implementation follows the original OpenPI structure for compatibility.
# Original implementation: https://github.com/Physical-Intelligence/openpi
# INFO 2026-03-20 01:04:15 ing_pi05.py:592 Enabled gradient checkpointing for PI05Pytorch model
# Loading model from: lerobot/pi05_base
# ✓ Loaded state dict from model.safetensors
# WARNING 2026-03-20 01:04:16 ng_pi05.py:1099 Vision embedding key might need handling: paligemma_with_expert.paligemma.model.vision_tower.vision_model.embeddings.patch_embedding.bias
# WARNING 2026-03-20 01:04:16 ng_pi05.py:1099 Vision embedding key might need handling: paligemma_with_expert.paligemma.model.vision_tower.vision_model.embeddings.patch_embedding.weight
# Remapped: action_in_proj.bias -> model.action_in_proj.bias
# Remapped: action_in_proj.weight -> model.action_in_proj.weight
# Remapped: action_out_proj.bias -> model.action_out_proj.bias
# Remapped: action_out_proj.weight -> model.action_out_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.lm_head.weight -> model.paligemma_with_expert.gemma_expert.lm_head.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight
# Remapped 812 state dict keys
# Loading model from: lerobot/pi05_base
# Loading model from: lerobot/pi05_base
# ✓ Loaded state dict from model.safetensors
# Remapped: action_in_proj.bias -> model.action_in_proj.bias
# Remapped: action_in_proj.weight -> model.action_in_proj.weight
# Remapped: action_out_proj.bias -> model.action_out_proj.bias
# Remapped: action_out_proj.weight -> model.action_out_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.lm_head.weight -> model.paligemma_with_expert.gemma_expert.lm_head.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight
# Remapped 812 state dict keys
# Loading model from: lerobot/pi05_base
# ✓ Loaded state dict from model.safetensors
# Remapped: action_in_proj.bias -> model.action_in_proj.bias
# Remapped: action_in_proj.weight -> model.action_in_proj.weight
# Remapped: action_out_proj.bias -> model.action_out_proj.bias
# Remapped: action_out_proj.weight -> model.action_out_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.lm_head.weight -> model.paligemma_with_expert.gemma_expert.lm_head.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight
# Remapped 812 state dict keys
# ✓ Loaded state dict from model.safetensors
# Remapped: action_in_proj.bias -> model.action_in_proj.bias
# Remapped: action_in_proj.weight -> model.action_in_proj.weight
# Remapped: action_out_proj.bias -> model.action_out_proj.bias
# Remapped: action_out_proj.weight -> model.action_out_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.lm_head.weight -> model.paligemma_with_expert.gemma_expert.lm_head.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight
# Remapped 812 state dict keys
# Warning: Could not remap state dict keys: Error(s) in loading state_dict for PI05Policy:
# 	Missing key(s) in state_dict: "model.paligemma_with_expert.paligemma.model.language_model.embed_tokens.weight".
# Warning: Could not remap state dict keys: Error(s) in loading state_dict for PI05Policy:
# 	Missing key(s) in state_dict: "model.paligemma_with_expert.paligemma.model.language_model.embed_tokens.weight".
# Warning: Could not remap state dict keys: Error(s) in loading state_dict for PI05Policy:
# 	Missing key(s) in state_dict: "model.paligemma_with_expert.paligemma.model.language_model.embed_tokens.weight".
# Warning: Could not remap state dict keys: Error(s) in loading state_dict for PI05Policy:
# 	Missing key(s) in state_dict: "model.paligemma_with_expert.paligemma.model.language_model.embed_tokens.weight".
# INFO 2026-03-20 01:04:19 ot_train.py:366 Creating optimizer and scheduler
# INFO 2026-03-20 01:04:19 hedulers.py:105 Auto-scaling LR scheduler: num_training_steps (400) < num_decay_steps (30000). Scaling warmup: 1000 → 13, decay: 30000 → 400 (scale factor: 0.013)
# INFO 2026-03-20 01:04:19 ot_train.py:401 Output dir: ckpt/clr-experiment-pi05
# INFO 2026-03-20 01:04:19 ot_train.py:408 cfg.steps=400 (400)
# INFO 2026-03-20 01:04:19 ot_train.py:409 dataset.num_frames=3562 (4K)
# INFO 2026-03-20 01:04:19 ot_train.py:410 dataset.num_episodes=3
# INFO 2026-03-20 01:04:19 ot_train.py:413 Effective batch size: 32 x 4 = 128
# INFO 2026-03-20 01:04:19 ot_train.py:414 num_learnable_params=3616757520 (4B)
# INFO 2026-03-20 01:04:19 ot_train.py:415 num_total_params=3616757520 (4B)
# INFO 2026-03-20 01:04:19 ot_train.py:471 Start offline training on a fixed dataset, with effective batch size: 128
# INFO 2026-03-20 01:06:39 ot_train.py:501 step:50 smpl:26K ep:22 epch:7.19 loss:0.177 grdn:1.481 lr:2.2e-05 updt_s:2.765 data_s:0.030
# WARNING 2026-03-20 01:06:39 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-03-20 01:08:57 ot_train.py:501 step:100 smpl:51K ep:43 epch:14.37 loss:0.071 grdn:0.340 lr:2.3e-05 updt_s:2.729 data_s:0.025
# WARNING 2026-03-20 01:08:57 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-03-20 01:11:15 ot_train.py:501 step:150 smpl:77K ep:65 epch:21.56 loss:0.051 grdn:0.335 lr:2.0e-05 updt_s:2.744 data_s:0.024
# WARNING 2026-03-20 01:11:15 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-03-20 01:13:34 ot_train.py:501 step:200 smpl:102K ep:86 epch:28.75 loss:0.047 grdn:0.302 lr:1.6e-05 updt_s:2.742 data_s:0.024
# WARNING 2026-03-20 01:13:34 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-03-20 01:15:52 ot_train.py:501 step:250 smpl:128K ep:108 epch:35.93 loss:0.040 grdn:0.315 lr:1.2e-05 updt_s:2.753 data_s:0.016
# WARNING 2026-03-20 01:15:52 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-03-20 01:18:11 ot_train.py:501 step:300 smpl:154K ep:129 epch:43.12 loss:0.041 grdn:0.307 lr:7.5e-06 updt_s:2.738 data_s:0.024
# WARNING 2026-03-20 01:18:11 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-03-20 01:20:29 ot_train.py:501 step:350 smpl:179K ep:151 epch:50.31 loss:0.037 grdn:0.309 lr:4.4e-06 updt_s:2.749 data_s:0.025
# WARNING 2026-03-20 01:20:29 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-03-20 01:22:48 ot_train.py:501 step:400 smpl:205K ep:172 epch:57.50 loss:0.039 grdn:0.296 lr:2.8e-06 updt_s:2.739 data_s:0.024
# WARNING 2026-03-20 01:22:48 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-03-20 01:22:48 ot_train.py:521 Checkpoint policy after step 400
# INFO 2026-03-20 01:23:20 ot_train.py:592 End of training
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...nt-pi05/model.safetensors:   0%|              |  131kB / 7.47GB
#
# Processing Files (0 / 1)      :   0%|              |  131kB / 7.47GB,  109kB/s
#
#   ...nt-pi05/model.safetensors:   0%|              |  131kB / 7.47GB
#
# Processing Files (0 / 1)      :   0%|              |  688kB / 7.47GB,  430kB/s
# New Data Upload               :   0%|              |  557kB /  134MB,  348kB/s
#
# Processing Files (0 / 1)      :   0%|              | 2.36MB / 7.47GB, 1.31MB/s
# New Data Upload               :   2%|▏             | 2.23MB /  134MB, 1.24MB/s
#
# Processing Files (0 / 1)      :   0%|              | 7.37MB / 7.47GB, 3.68MB/s
# New Data Upload               :   5%|▊             | 7.24MB /  134MB, 3.62MB/s
#
# Processing Files (0 / 1)      :   0%|              | 12.9MB / 7.47GB, 5.88MB/s
# New Data Upload               :  10%|█▎            | 12.8MB /  134MB, 5.82MB/s
#
# Processing Files (0 / 1)      :   0%|              | 24.1MB / 7.47GB, 10.0MB/s
# New Data Upload               :  18%|██▍           | 23.9MB /  134MB, 9.97MB/s
#
# Processing Files (0 / 1)      :   0%|              | 35.2MB / 7.47GB, 13.5MB/s
# New Data Upload               :  26%|███▋          | 35.1MB /  134MB, 13.5MB/s
#
# Processing Files (0 / 1)      :   1%|              | 43.0MB / 7.47GB, 15.4MB/s
# New Data Upload               :  32%|████▍         | 42.9MB /  134MB, 15.3MB/s
#
# Processing Files (0 / 1)      :   1%|              | 54.1MB / 7.47GB, 18.0MB/s
# New Data Upload               :  40%|█████▋        | 54.0MB /  134MB, 18.0MB/s
#
# Processing Files (0 / 1)      :   1%|              | 65.8MB / 7.47GB, 20.6MB/s
# New Data Upload               :  49%|██████▊       | 65.7MB /  134MB, 20.5MB/s
#
# Processing Files (0 / 1)      :   1%|▏             | 66.9MB / 7.47GB, 19.7MB/s
# New Data Upload               :  50%|██████▉       | 66.8MB /  134MB, 19.7MB/s
#
#   ...nt-pi05/model.safetensors:   1%|▏             | 66.9MB / 7.47GB
#
#   ...nt-pi05/model.safetensors:   1%|▏             | 66.9MB / 7.47GB
#
#   ...nt-pi05/model.safetensors:   1%|▏             | 66.9MB / 7.47GB
#
#   ...nt-pi05/model.safetensors:   1%|▏             | 66.9MB / 7.47GB
#
# Processing Files (0 / 1)      :   1%|▏             | 71.1MB / 7.47GB, 16.2MB/s
# New Data Upload               :  35%|████▉         | 71.0MB /  201MB, 16.1MB/s
#
# Processing Files (0 / 1)      :   1%|▏             | 80.6MB / 7.47GB, 17.5MB/s
# New Data Upload               :  30%|████▏         | 80.4MB /  268MB, 17.5MB/s
#
# Processing Files (0 / 1)      :   1%|▏             | 92.2MB / 7.47GB, 19.2MB/s
# New Data Upload               :  34%|████▊         | 92.1MB /  268MB, 19.2MB/s
#
# Processing Files (0 / 1)      :   1%|▏             |  102MB / 7.47GB, 20.4MB/s
# New Data Upload               :  38%|█████▎        |  102MB /  268MB, 20.4MB/s
#
# Processing Files (0 / 1)      :   2%|▏             |  116MB / 7.47GB, 22.2MB/s
# New Data Upload               :  34%|████▊         |  115MB /  335MB, 22.2MB/s
#
# Processing Files (0 / 1)      :   2%|▎             |  141MB / 7.47GB, 26.1MB/s
# New Data Upload               :  35%|████▉         |  141MB /  402MB, 26.1MB/s
#
# Processing Files (0 / 1)      :   2%|▎             |  171MB / 7.47GB, 30.6MB/s
# New Data Upload               :  42%|█████▉        |  171MB /  402MB, 30.5MB/s
#
# Processing Files (0 / 1)      :   3%|▎             |  197MB / 7.47GB, 34.0MB/s
# New Data Upload               :  49%|██████▊       |  197MB /  402MB, 34.0MB/s
#
# Processing Files (0 / 1)      :   3%|▍             |  228MB / 7.47GB, 38.0MB/s
# New Data Upload               :  48%|██████▋       |  224MB /  470MB, 37.3MB/s
#
# Processing Files (0 / 1)      :   4%|▍             |  264MB / 7.47GB, 42.5MB/s
# New Data Upload               :  55%|███████▋      |  260MB /  470MB, 41.9MB/s
#
# Processing Files (0 / 1)      :   5%|▋             |  356MB / 7.47GB, 55.6MB/s
#
# Processing Files (0 / 1)      :   6%|▉             |  482MB / 7.47GB, 73.0MB/s
# New Data Upload               :  71%|█████████▉    |  333MB /  470MB, 50.4MB/s
#
# Processing Files (0 / 1)      :   8%|█▏            |  615MB / 7.47GB, 90.4MB/s
# New Data Upload               :  79%|███████████   |  370MB /  470MB, 54.3MB/s
#
# Processing Files (0 / 1)      :  10%|█▍            |  737MB / 7.47GB,  105MB/s
# New Data Upload               :  86%|████████████  |  404MB /  470MB, 57.6MB/s
#
# Processing Files (0 / 1)      :  11%|█▌            |  848MB / 7.47GB,  118MB/s
# New Data Upload               :  89%|████████████▍ |  419MB /  470MB, 58.2MB/s
#
# Processing Files (0 / 1)      :  13%|█▊            |  960MB / 7.47GB,  130MB/s
# New Data Upload               :  94%|█████████████▏|  443MB /  470MB, 59.9MB/s
#
# Processing Files (0 / 1)      :  13%|█▊            |  991MB / 7.47GB,  130MB/s
# New Data Upload               :  86%|███████████▉  |  460MB /  537MB, 60.5MB/s
#
# Processing Files (0 / 1)      :  13%|█▉            | 1.00GB / 7.47GB,  129MB/s
# New Data Upload               :  78%|██████████▉   |  472MB /  604MB, 60.5MB/s
#
# Processing Files (0 / 1)      :  14%|█▉            | 1.02GB / 7.47GB,  128MB/s
# New Data Upload               :  81%|███████████▎  |  489MB /  604MB, 61.2MB/s
#
# Processing Files (0 / 1)      :  14%|█▉            | 1.04GB / 7.47GB,  127MB/s
# New Data Upload               :  77%|██████████▋   |  514MB /  671MB, 62.6MB/s
#
# Processing Files (0 / 1)      :  14%|██            | 1.07GB / 7.47GB,  127MB/s
# New Data Upload               :  73%|██████████▏   |  537MB /  738MB, 63.9MB/s
#
# Processing Files (0 / 1)      :  15%|██            | 1.10GB / 7.47GB,  128MB/s
# New Data Upload               :  71%|█████████▉    |  574MB /  805MB, 66.7MB/s
#
# Processing Files (0 / 1)      :  15%|██▏           | 1.15GB / 7.47GB,  131MB/s
# New Data Upload               :  77%|██████████▊   |  621MB /  805MB, 70.5MB/s
#
# Processing Files (0 / 1)      :  16%|██▎           | 1.20GB / 7.47GB,  134MB/s
# New Data Upload               :  77%|██████████▊   |  674MB /  872MB, 74.8MB/s
#
# Processing Files (0 / 1)      :  17%|██▎           | 1.24GB / 7.47GB,  135MB/s
# New Data Upload               :  75%|██████████▌   |  707MB /  939MB, 76.8MB/s
#
# Processing Files (0 / 1)      :  17%|██▍           | 1.28GB / 7.47GB,  136MB/s
# New Data Upload               :  80%|███████████▏  |  748MB /  939MB, 79.6MB/s
#
# Processing Files (0 / 1)      :  18%|██▍           | 1.32GB / 7.47GB,  137MB/s
# New Data Upload               :  78%|██████████▉   |  789MB / 1.01GB, 82.2MB/s
#
# Processing Files (0 / 1)      :  18%|██▌           | 1.37GB / 7.47GB,  140MB/s
# New Data Upload               :  77%|██████████▊   |  826MB / 1.07GB, 84.3MB/s
#
# Processing Files (0 / 1)      :  20%|██▊           | 1.50GB / 7.47GB,  150MB/s
# New Data Upload               :  81%|███████████▎  |  868MB / 1.07GB, 86.8MB/s
#
# Processing Files (0 / 1)      :  22%|███           | 1.65GB / 7.47GB,  161MB/s
# New Data Upload               :  85%|███████████▉  |  913MB / 1.07GB, 89.5MB/s
#
# Processing Files (0 / 1)      :  24%|███▎          | 1.78GB / 7.47GB,  175MB/s
# New Data Upload               :  90%|████████████▌ |  962MB / 1.07GB, 94.4MB/s
#
# Processing Files (0 / 1)      :  26%|███▌          | 1.92GB / 7.47GB,  188MB/s
# New Data Upload               :  93%|█████████████ | 1.00GB / 1.07GB, 98.2MB/s
#
# Processing Files (0 / 1)      :  27%|███▊          | 2.04GB / 7.47GB,  200MB/s
# New Data Upload               :  96%|█████████████▌| 1.03GB / 1.07GB,  101MB/s
#
# Processing Files (0 / 1)      :  29%|████          | 2.15GB / 7.47GB,  211MB/s
# New Data Upload               :  99%|█████████████▊| 1.06GB / 1.07GB,  104MB/s
#
# Processing Files (0 / 1)      :  30%|████▏         | 2.26GB / 7.47GB,  222MB/s
# New Data Upload               : 100%|█████████████▉| 1.07GB / 1.07GB,  105MB/s
#
# Processing Files (0 / 1)      :  31%|████▍         | 2.35GB / 7.47GB,  230MB/s
# New Data Upload               : 100%|█████████████▉| 1.07GB / 1.07GB,  105MB/s
#
# Processing Files (0 / 1)      :  33%|████▌         | 2.44GB / 7.47GB,  240MB/s
#
# Processing Files (0 / 1)      :  34%|████▋         | 2.53GB / 7.47GB,  248MB/s
# New Data Upload               : 100%|█████████████▉| 1.07GB / 1.07GB,  105MB/s
#
# Processing Files (0 / 1)      :  35%|████▉         | 2.63GB / 7.47GB,  257MB/s
#
# Processing Files (0 / 1)      :  36%|████▉         | 2.65GB / 7.47GB,  259MB/s
#
# Processing Files (0 / 1)      :  36%|████▉         | 2.66GB / 7.47GB,  259MB/s
# New Data Upload               :  94%|█████████████▏| 1.08GB / 1.14GB,  104MB/s
#
# Processing Files (0 / 1)      :  36%|████▉         | 2.67GB / 7.47GB,  259MB/s
# New Data Upload               :  90%|████████████▌ | 1.08GB / 1.21GB,  104MB/s
#
# Processing Files (0 / 1)      :  36%|█████         | 2.68GB / 7.47GB,  260MB/s
# New Data Upload               :  87%|████████████  | 1.10GB / 1.27GB,  105MB/s
#
# Processing Files (0 / 1)      :  36%|█████         | 2.71GB / 7.47GB,  261MB/s
# New Data Upload               :  88%|████████████▎ | 1.13GB / 1.27GB,  106MB/s
#
# Processing Files (0 / 1)      :  37%|█████         | 2.73GB / 7.47GB,  263MB/s
# New Data Upload               :  86%|████████████  | 1.15GB / 1.34GB,  108MB/s
#
# Processing Files (0 / 1)      :  37%|█████▏        | 2.77GB / 7.47GB,  265MB/s
# New Data Upload               :  84%|███████████▊  | 1.18GB / 1.41GB,  110MB/s
#
# Processing Files (0 / 1)      :  38%|█████▎        | 2.81GB / 7.47GB,  269MB/s
# New Data Upload               :  87%|████████████▏ | 1.23GB / 1.41GB,  114MB/s
#
# Processing Files (0 / 1)      :  38%|█████▎        | 2.85GB / 7.47GB,  273MB/s
# New Data Upload               :  86%|████████████  | 1.27GB / 1.48GB,  118MB/s
#
# Processing Files (0 / 1)      :  39%|█████▍        | 2.88GB / 7.47GB,  276MB/s
# New Data Upload               :  84%|███████████▊  | 1.30GB / 1.54GB,  121MB/s
#
# Processing Files (0 / 1)      :  39%|█████▍        | 2.91GB / 7.47GB,  279MB/s
# New Data Upload               :  83%|███████████▌  | 1.33GB / 1.61GB,  124MB/s
#
# Processing Files (0 / 1)      :  39%|█████▌        | 2.95GB / 7.47GB,  283MB/s
# New Data Upload               :  85%|███████████▉  | 1.37GB / 1.61GB,  128MB/s
#
# Processing Files (0 / 1)      :  40%|█████▌        | 2.99GB / 7.47GB,  286MB/s
# New Data Upload               :  84%|███████████▊  | 1.41GB / 1.68GB,  131MB/s
#
# Processing Files (0 / 1)      :  41%|█████▋        | 3.03GB / 7.47GB,  289MB/s
# New Data Upload               :  83%|███████████▋  | 1.45GB / 1.74GB,  134MB/s
#
# Processing Files (0 / 1)      :  41%|█████▊        | 3.08GB / 7.47GB,  293MB/s
# New Data Upload               :  86%|████████████  | 1.50GB / 1.74GB,  138MB/s
#
# Processing Files (0 / 1)      :  42%|█████▊        | 3.14GB / 7.47GB,  297MB/s
# New Data Upload               :  86%|████████████  | 1.55GB / 1.81GB,  142MB/s
#
# Processing Files (0 / 1)      :  43%|█████▉        | 3.19GB / 7.47GB,  301MB/s
# New Data Upload               :  89%|████████████▍ | 1.61GB / 1.81GB,  146MB/s
#
# Processing Files (0 / 1)      :  43%|██████        | 3.25GB / 7.47GB,  304MB/s
# New Data Upload               :  89%|████████████▍ | 1.66GB / 1.88GB,  149MB/s
#
# Processing Files (0 / 1)      :  44%|██████▏       | 3.30GB / 7.47GB,  307MB/s
# New Data Upload               :  88%|████████████▎ | 1.72GB / 1.94GB,  152MB/s
#
# Processing Files (0 / 1)      :  45%|██████▎       | 3.35GB / 7.47GB,  309MB/s
# New Data Upload               :  88%|████████████▎ | 1.77GB / 2.01GB,  154MB/s
#
# Processing Files (0 / 1)      :  45%|██████▎       | 3.40GB / 7.47GB,  311MB/s
# New Data Upload               :  87%|████████████▏ | 1.82GB / 2.08GB,  156MB/s
#
# Processing Files (0 / 1)      :  46%|██████▍       | 3.46GB / 7.47GB,  313MB/s
# New Data Upload               :  87%|████████████▏ | 1.87GB / 2.15GB,  158MB/s
#
# Processing Files (0 / 1)      :  47%|██████▌       | 3.52GB / 7.47GB,  310MB/s
# New Data Upload               :  90%|████████████▌ | 1.93GB / 2.15GB,  161MB/s
#
# Processing Files (0 / 1)      :  48%|██████▋       | 3.57GB / 7.47GB,  303MB/s
# New Data Upload               :  93%|████████████▉ | 1.99GB / 2.15GB,  162MB/s
#
# Processing Files (0 / 1)      :  48%|██████▊       | 3.62GB / 7.47GB,  294MB/s
# New Data Upload               :  92%|████████████▉ | 2.04GB / 2.21GB,  163MB/s
#
# Processing Files (0 / 1)      :  49%|██████▉       | 3.67GB / 7.47GB,  288MB/s
# New Data Upload               :  94%|█████████████▏| 2.09GB / 2.21GB,  165MB/s
#
# Processing Files (0 / 1)      :  50%|██████▉       | 3.70GB / 7.47GB,  280MB/s
# New Data Upload               :  93%|█████████████ | 2.12GB / 2.28GB,  167MB/s
#
# Processing Files (0 / 1)      :  50%|██████▉       | 3.73GB / 7.47GB,  272MB/s
# New Data Upload               :  94%|█████████████▏| 2.15GB / 2.28GB,  167MB/s
#
# Processing Files (0 / 1)      :  50%|███████       | 3.76GB / 7.47GB,  272MB/s
# New Data Upload               :  93%|█████████████ | 2.18GB / 2.35GB,  169MB/s
#
# Processing Files (0 / 1)      :  51%|███████       | 3.80GB / 7.47GB,  274MB/s
# New Data Upload               :  92%|████████████▊ | 2.22GB / 2.41GB,  171MB/s
#
# Processing Files (0 / 1)      :  51%|███████▏      | 3.84GB / 7.47GB,  276MB/s
# New Data Upload               :  93%|█████████████ | 2.25GB / 2.41GB,  173MB/s
#
# Processing Files (0 / 1)      :  52%|███████▎      | 3.88GB / 7.47GB,  278MB/s
# New Data Upload               :  93%|████████████▉ | 2.30GB / 2.48GB,  175MB/s
#
# Processing Files (0 / 1)      :  52%|███████▎      | 3.92GB / 7.47GB,  280MB/s
# New Data Upload               :  94%|█████████████▏| 2.34GB / 2.48GB,  177MB/s
#
# Processing Files (0 / 1)      :  53%|███████▍      | 3.97GB / 7.47GB,  280MB/s
# New Data Upload               :  94%|█████████████ | 2.38GB / 2.55GB,  177MB/s
#
# Processing Files (0 / 1)      :  53%|███████▍      | 4.00GB / 7.47GB,  279MB/s
# New Data Upload               :  92%|████████████▉ | 2.42GB / 2.62GB,  176MB/s
#
# Processing Files (0 / 1)      :  54%|███████▌      | 4.04GB / 7.47GB,  278MB/s
# New Data Upload               :  94%|█████████████▏| 2.46GB / 2.62GB,  175MB/s
#
# Processing Files (0 / 1)      :  55%|███████▋      | 4.08GB / 7.47GB,  279MB/s
# New Data Upload               :  93%|█████████████ | 2.50GB / 2.68GB,  176MB/s
#
# Processing Files (0 / 1)      :  55%|███████▋      | 4.11GB / 7.47GB,  278MB/s
# New Data Upload               :  94%|█████████████▏| 2.53GB / 2.68GB,  175MB/s
#
# Processing Files (0 / 1)      :  56%|███████▊      | 4.15GB / 7.47GB,  277MB/s
# New Data Upload               :  93%|█████████████ | 2.57GB / 2.75GB,  174MB/s
#
# Processing Files (0 / 1)      :  56%|███████▊      | 4.19GB / 7.47GB,  276MB/s
# New Data Upload               :  92%|████████████▉ | 2.60GB / 2.82GB,  174MB/s
#
# Processing Files (0 / 1)      :  57%|███████▉      | 4.24GB / 7.47GB,  268MB/s
# New Data Upload               :  94%|█████████████▏| 2.65GB / 2.82GB,  175MB/s
#
# Processing Files (0 / 1)      :  57%|███████▉      | 4.27GB / 7.47GB,  257MB/s
# New Data Upload               :  93%|█████████████ | 2.69GB / 2.88GB,  174MB/s
#
# Processing Files (0 / 1)      :  58%|████████      | 4.31GB / 7.47GB,  248MB/s
# New Data Upload               :  93%|████████████▉ | 2.73GB / 2.95GB,  173MB/s
#
# Processing Files (0 / 1)      :  58%|████████▏     | 4.36GB / 7.47GB,  239MB/s
# New Data Upload               :  94%|█████████████▏| 2.77GB / 2.95GB,  174MB/s
#
# Processing Files (0 / 1)      :  59%|████████▏     | 4.39GB / 7.47GB,  230MB/s
# New Data Upload               :  93%|█████████████ | 2.81GB / 3.02GB,  174MB/s
#
# Processing Files (0 / 1)      :  59%|████████▎     | 4.44GB / 7.47GB,  224MB/s
# New Data Upload               :  94%|█████████████▏| 2.84GB / 3.02GB,  174MB/s
#
# Processing Files (0 / 1)      :  61%|████████▌     | 4.57GB / 7.47GB,  226MB/s
# New Data Upload               :  95%|█████████████▎| 2.88GB / 3.02GB,  177MB/s
#
# Processing Files (0 / 1)      :  63%|████████▊     | 4.71GB / 7.47GB,  231MB/s
# New Data Upload               :  97%|█████████████▌| 2.92GB / 3.02GB,  182MB/s
#
# Processing Files (0 / 1)      :  64%|████████▉     | 4.76GB / 7.47GB,  227MB/s
# New Data Upload               :  96%|█████████████▍| 2.96GB / 3.08GB,  185MB/s
#
# Processing Files (0 / 1)      :  64%|████████▉     | 4.79GB / 7.47GB,  221MB/s
# New Data Upload               :  97%|█████████████▌| 2.99GB / 3.08GB,  188MB/s
#
# Processing Files (0 / 1)      :  64%|█████████     | 4.82GB / 7.47GB,  215MB/s
# New Data Upload               :  96%|█████████████▍| 3.02GB / 3.15GB,  191MB/s
#
# Processing Files (0 / 1)      :  65%|█████████     | 4.85GB / 7.47GB,  215MB/s
# New Data Upload               :  95%|█████████████▎| 3.05GB / 3.22GB,  194MB/s
#
# Processing Files (0 / 1)      :  65%|█████████▏    | 4.87GB / 7.47GB,  217MB/s
# New Data Upload               :  96%|█████████████▎| 3.07GB / 3.22GB,  196MB/s
#
# Processing Files (0 / 1)      :  66%|█████████▏    | 4.90GB / 7.47GB,  219MB/s
# New Data Upload               :  94%|█████████████▏| 3.10GB / 3.29GB,  198MB/s
#
# Processing Files (0 / 1)      :  66%|█████████▏    | 4.93GB / 7.47GB,  220MB/s
# New Data Upload               :  93%|█████████████ | 3.13GB / 3.35GB,  199MB/s
#
# Processing Files (0 / 1)      :  67%|█████████▎    | 4.97GB / 7.47GB,  222MB/s
# New Data Upload               :  93%|████████████▉ | 3.17GB / 3.42GB,  201MB/s
#
# Processing Files (0 / 1)      :  67%|█████████▍    | 5.02GB / 7.47GB,  224MB/s
# New Data Upload               :  92%|████████████▉ | 3.22GB / 3.49GB,  202MB/s
#
# Processing Files (0 / 1)      :  68%|█████████▍    | 5.07GB / 7.47GB,  226MB/s
# New Data Upload               :  94%|█████████████▏| 3.27GB / 3.49GB,  204MB/s
#
# Processing Files (0 / 1)      :  69%|█████████▌    | 5.12GB / 7.47GB,  227MB/s
# New Data Upload               :  94%|█████████████ | 3.32GB / 3.55GB,  206MB/s
#
# Processing Files (0 / 1)      :  69%|█████████▋    | 5.17GB / 7.47GB,  228MB/s
# New Data Upload               :  93%|█████████████ | 3.37GB / 3.62GB,  206MB/s
#
# Processing Files (0 / 1)      :  70%|█████████▊    | 5.22GB / 7.47GB,  230MB/s
# New Data Upload               :  95%|█████████████▏| 3.42GB / 3.62GB,  209MB/s
#
# Processing Files (0 / 1)      :  71%|█████████▊    | 5.27GB / 7.47GB,  231MB/s
# New Data Upload               :  94%|█████████████▏| 3.47GB / 3.69GB,  210MB/s
#
# Processing Files (0 / 1)      :  71%|█████████▉    | 5.30GB / 7.47GB,  230MB/s
# New Data Upload               :  93%|█████████████ | 3.50GB / 3.76GB,  209MB/s
#
# Processing Files (0 / 1)      :  72%|██████████    | 5.35GB / 7.47GB,  231MB/s
# New Data Upload               :  93%|████████████▉ | 3.55GB / 3.82GB,  210MB/s
#
# Processing Files (0 / 1)      :  72%|██████████    | 5.40GB / 7.47GB,  232MB/s
# New Data Upload               :  93%|████████████▉ | 3.60GB / 3.89GB,  211MB/s
#
# Processing Files (0 / 1)      :  73%|██████████▏   | 5.45GB / 7.47GB,  232MB/s
# New Data Upload               :  92%|████████████▉ | 3.65GB / 3.96GB,  211MB/s
#
# Processing Files (0 / 1)      :  74%|██████████▎   | 5.51GB / 7.47GB,  233MB/s
# New Data Upload               :  94%|█████████████▏| 3.71GB / 3.96GB,  211MB/s
#
# Processing Files (0 / 1)      :  75%|██████████▍   | 5.59GB / 7.47GB,  235MB/s
# New Data Upload               :  94%|█████████████▏| 3.79GB / 4.02GB,  214MB/s
#
# Processing Files (0 / 1)      :  75%|██████████▌   | 5.64GB / 7.47GB,  235MB/s
# New Data Upload               :  94%|█████████████▏| 3.84GB / 4.09GB,  214MB/s
#
# Processing Files (0 / 1)      :  76%|██████████▋   | 5.70GB / 7.47GB,  236MB/s
# New Data Upload               :  94%|█████████████▏| 3.90GB / 4.16GB,  214MB/s
#
# Processing Files (0 / 1)      :  77%|██████████▊   | 5.76GB / 7.47GB,  236MB/s
# New Data Upload               :  95%|█████████████▎| 3.96GB / 4.16GB,  214MB/s
#
# Processing Files (0 / 1)      :  78%|██████████▉   | 5.82GB / 7.47GB,  237MB/s
# New Data Upload               :  95%|█████████████▎| 4.02GB / 4.22GB,  216MB/s
#
# Processing Files (0 / 1)      :  78%|██████████▉   | 5.85GB / 7.47GB,  235MB/s
# New Data Upload               :  94%|█████████████▏| 4.05GB / 4.29GB,  214MB/s
#
# Processing Files (0 / 1)      :  79%|███████████   | 5.90GB / 7.47GB,  234MB/s
# New Data Upload               :  94%|█████████████▏| 4.10GB / 4.36GB,  213MB/s
#
# Processing Files (0 / 1)      :  80%|███████████▏  | 5.95GB / 7.47GB,  233MB/s
# New Data Upload               :  94%|█████████████ | 4.15GB / 4.43GB,  212MB/s
#
# Processing Files (0 / 1)      :  80%|███████████▏  | 5.99GB / 7.47GB,  233MB/s
# New Data Upload               :  95%|█████████████▎| 4.19GB / 4.43GB,  212MB/s
#
# Processing Files (0 / 1)      :  81%|███████████▎  | 6.03GB / 7.47GB,  231MB/s
# New Data Upload               :  94%|█████████████▏| 4.23GB / 4.49GB,  210MB/s
#
# Processing Files (0 / 1)      :  81%|███████████▍  | 6.08GB / 7.47GB,  233MB/s
# New Data Upload               :  95%|█████████████▎| 4.28GB / 4.49GB,  211MB/s
#
# Processing Files (0 / 1)      :  82%|███████████▍  | 6.12GB / 7.47GB,  235MB/s
# New Data Upload               :  95%|█████████████▎| 4.33GB / 4.56GB,  213MB/s
# Processing Files (0 / 1)      :  83%|███████████▌  | 6.17GB / 7.47GB,  236MB/s
# New Data Upload               :  94%|█████████████▏| 4.37GB / 4.63GB,  214MB/s
#
# Processing Files (0 / 1)      :  83%|███████████▋  | 6.21GB / 7.47GB,  237MB/s
# New Data Upload               :  94%|█████████████▏| 4.41GB / 4.69GB,  216MB/s
#
# Processing Files (0 / 1)      :  84%|███████████▊  | 6.28GB / 7.47GB,  240MB/s
# New Data Upload               :  95%|█████████████▎| 4.48GB / 4.69GB,  218MB/s
#
# Processing Files (0 / 1)      :  85%|███████████▊  | 6.32GB / 7.47GB,  240MB/s
# New Data Upload               :  95%|█████████████▎| 4.52GB / 4.76GB,  218MB/s
#
# Processing Files (0 / 1)      :  85%|███████████▉  | 6.37GB / 7.47GB,  240MB/s
# New Data Upload               :  95%|█████████████▏| 4.57GB / 4.83GB,  218MB/s
#
# Processing Files (0 / 1)      :  86%|████████████  | 6.42GB / 7.47GB,  241MB/s
# New Data Upload               :  96%|█████████████▍| 4.62GB / 4.83GB,  219MB/s
#
# Processing Files (0 / 1)      :  87%|████████████  | 6.47GB / 7.47GB,  242MB/s
# New Data Upload               :  95%|█████████████▎| 4.67GB / 4.90GB,  221MB/s
#
# Processing Files (0 / 1)      :  87%|████████████▏ | 6.50GB / 7.47GB,  241MB/s
# New Data Upload               :  95%|█████████████▎| 4.70GB / 4.96GB,  220MB/s
#
# Processing Files (0 / 1)      :  88%|████████████▎ | 6.55GB / 7.47GB,  242MB/s
# New Data Upload               :  96%|█████████████▍| 4.75GB / 4.96GB,  221MB/s
#
# Processing Files (0 / 1)      :  88%|████████████▍ | 6.61GB / 7.47GB,  245MB/s
# New Data Upload               :  96%|█████████████▍| 4.81GB / 5.03GB,  224MB/s
#
# Processing Files (0 / 1)      :  89%|████████████▍ | 6.66GB / 7.47GB,  246MB/s
# New Data Upload               :  95%|█████████████▎| 4.86GB / 5.10GB,  224MB/s
#
# Processing Files (0 / 1)      :  90%|████████████▌ | 6.70GB / 7.47GB,  247MB/s
# New Data Upload               :  96%|█████████████▍| 4.90GB / 5.10GB,  225MB/s
#
# Processing Files (0 / 1)      :  90%|████████████▋ | 6.75GB / 7.47GB,  247MB/s
# New Data Upload               :  96%|█████████████▍| 4.95GB / 5.16GB,  225MB/s
#
# Processing Files (0 / 1)      :  91%|████████████▋ | 6.79GB / 7.47GB,  248MB/s
# New Data Upload               :  95%|█████████████▎| 5.00GB / 5.23GB,  226MB/s
#
# Processing Files (0 / 1)      :  91%|████████████▊ | 6.84GB / 7.47GB,  247MB/s
# New Data Upload               :  96%|█████████████▍| 5.04GB / 5.23GB,  226MB/s
#
# Processing Files (0 / 1)      :  92%|████████████▉ | 6.88GB / 7.47GB,  247MB/s
# New Data Upload               :  96%|█████████████▍| 5.08GB / 5.30GB,  226MB/s
#
# Processing Files (0 / 1)      :  93%|████████████▉ | 6.92GB / 7.47GB,  249MB/s
# New Data Upload               :  97%|█████████████▌| 5.13GB / 5.30GB,  227MB/s
#
# Processing Files (0 / 1)      :  93%|█████████████ | 6.97GB / 7.47GB,  248MB/s
# New Data Upload               :  96%|█████████████▍| 5.17GB / 5.36GB,  228MB/s
#
# Processing Files (0 / 1)      :  94%|█████████████ | 7.01GB / 7.47GB,  239MB/s
# New Data Upload               :  96%|█████████████▍| 5.21GB / 5.43GB,  228MB/s
#
# Processing Files (0 / 1)      :  94%|█████████████▏| 7.04GB / 7.47GB,  229MB/s
# New Data Upload               :  95%|█████████████▎| 5.24GB / 5.50GB,  227MB/s
#
# Processing Files (0 / 1)      :  95%|█████████████▎| 7.08GB / 7.47GB,  227MB/s
# New Data Upload               :  96%|█████████████▍| 5.28GB / 5.50GB,  227MB/s
#
# Processing Files (0 / 1)      :  95%|█████████████▎| 7.14GB / 7.47GB,  230MB/s
# New Data Upload               :  96%|█████████████▍| 5.34GB / 5.57GB,  230MB/s
#
# Processing Files (0 / 1)      :  96%|█████████████▍| 7.17GB / 7.47GB,  231MB/s
# New Data Upload               :  95%|█████████████▎| 5.37GB / 5.63GB,  231MB/s
#
# Processing Files (0 / 1)      :  97%|█████████████▌| 7.24GB / 7.47GB,  234MB/s
# New Data Upload               :  96%|█████████████▍| 5.44GB / 5.67GB,  234MB/s
#
# Processing Files (0 / 1)      :  98%|█████████████▋| 7.30GB / 7.47GB,  238MB/s
# New Data Upload               :  97%|█████████████▌| 5.50GB / 5.67GB,  238MB/s
#
# Processing Files (0 / 1)      :  98%|█████████████▊| 7.35GB / 7.47GB,  241MB/s
# New Data Upload               :  98%|█████████████▋| 5.55GB / 5.67GB,  241MB/s
#
# Processing Files (0 / 1)      :  99%|█████████████▊| 7.40GB / 7.47GB,  242MB/s
# New Data Upload               :  99%|█████████████▊| 5.60GB / 5.67GB,  242MB/s
#
# Processing Files (0 / 1)      :  99%|█████████████▉| 7.42GB / 7.47GB,  240MB/s
# New Data Upload               :  99%|█████████████▊| 5.62GB / 5.67GB,  240MB/s
#
# Processing Files (0 / 1)      : 100%|█████████████▉| 7.44GB / 7.47GB,  238MB/s
# New Data Upload               :  99%|█████████████▉| 5.64GB / 5.67GB,  238MB/s
#
# Processing Files (0 / 1)      : 100%|█████████████▉| 7.46GB / 7.47GB,  234MB/s
# New Data Upload               : 100%|█████████████▉| 5.66GB / 5.67GB,  234MB/s
#
# Processing Files (0 / 1)      : 100%|█████████████▉| 7.47GB / 7.47GB,  230MB/s
# New Data Upload               : 100%|█████████████▉| 5.67GB / 5.67GB,  230MB/s
#
# Processing Files (0 / 1)      : 100%|█████████████▉| 7.47GB / 7.47GB,  226MB/s
# New Data Upload               : 100%|█████████████▉| 5.67GB / 5.67GB,  226MB/s
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
# Processing Files (0 / 1)      : 100%|█████████████▉| 7.47GB / 7.47GB,  208MB/s
# New Data Upload               : 100%|█████████████▉| 5.67GB / 5.67GB,  208MB/s
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
# Processing Files (1 / 1)      : 100%|██████████████| 7.47GB / 7.47GB, 90.4MB/s
# New Data Upload               : 100%|██████████████| 5.67GB / 5.67GB, 90.4MB/s
#
#   ...nt-pi05/model.safetensors: 100%|██████████████| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|██████████████| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|██████████████| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|██████████████| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|██████████████| 7.47GB / 7.47GB
#
# Processing Files (1 / 1)      : 100%|██████████████| 7.47GB / 7.47GB, 63.7MB/s
# New Data Upload               : 100%|██████████████| 5.67GB / 5.67GB, 63.7MB/s
#   ...nt-pi05/model.safetensors: 100%|██████████████| 7.47GB / 7.47GB
# INFO 2026-03-20 01:24:11 etrained.py:245 Model pushed to https://huggingface.co/gimarchetti/clr-experiment-pi05
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...zer_processor.safetensors: 100%|██████████████| 10.8kB / 10.8kB
#
# Processing Files (1 / 1)      : 100%|██████████████| 10.8kB / 10.8kB,   ???B/s
# New Data Upload               : 100%|██████████████| 10.8kB / 10.8kB,   ???B/s
#
#   ...zer_processor.safetensors: 100%|██████████████| 10.8kB / 10.8kB
#
#   ...zer_processor.safetensors: 100%|██████████████| 10.8kB / 10.8kB
#
#   ...zer_processor.safetensors: 100%|██████████████| 10.8kB / 10.8kB
#
#   ...zer_processor.safetensors: 100%|██████████████| 10.8kB / 10.8kB
#
#   ...zer_processor.safetensors: 100%|██████████████| 10.8kB / 10.8kB
#
# Processing Files (1 / 1)      : 100%|██████████████| 10.8kB / 10.8kB,  0.00B/s
# New Data Upload               : 100%|██████████████| 10.8kB / 10.8kB,  0.00B/s
#   ...zer_processor.safetensors: 100%|██████████████| 10.8kB / 10.8kB
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...zer_processor.safetensors: 100%|██████████████| 10.8kB / 10.8kB
#
# Processing Files (1 / 1)      : 100%|██████████████| 10.8kB / 10.8kB,   ???B/s
#
# Processing Files (1 / 1)      : 100%|██████████████| 10.8kB / 10.8kB,  0.00B/s
# New Data Upload               : |                  |  0.00B /  0.00B,  0.00B/s
#   ...zer_processor.safetensors: 100%|██████████████| 10.8kB / 10.8kB

# %% [markdown]
# ## Train GR00T N 1.5 TO BE DONE YET

# %%
# !pip install ninja "packaging>=24.2,<26.0"
# !pip install peft
# !pip install dm-tree==0.1.9
# !pip install -U transformers
# !pip install flash-attn==2.7.3 --no-build-isolation

# %%
# !lerobot-train\
    --dataset.repo_id=Jeongeun/tutorial_v2 \
    --dataset.root=dataset/leader_data \
    --policy.type=groot \
    --policy.repo_id=={YOUR REPO} \
    --output_dir=ckpt/tutorial_v2_groot \
    --job_name=tutorial_v2_groot \
    --wandb.enable=false \
    --steps=20000 \
    --policy.chunk_size=20 \
    --policy.n_action_steps=20 \
    --batch_size=32
