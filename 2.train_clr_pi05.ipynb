# %% [markdown]
# ## Train pi0.5

# %%
from datetime import datetime
import os
from dotenv import load_dotenv
load_dotenv()  # loads HF_TOKEN and WANDB_API_KEY from .env
## Set NCCL environment variables for distributed training in GCP G4 
## single instance, multi-GPU setup. Adjust the interface name (e.g., "ens3") as needed for your specific instance type.
os.environ.pop("NCCL_NET", None) # on single instance, multi-GPU setup, NCCL_NET should not be set to "IB" or "TCP"
os.environ["NCCL_SOCKET_IFNAME"] = "ens3" # Adjust "ens3" to the correct network interface for your GCP instance (e.g., "ens4", "eth0", etc.)
os.environ["NCCL_P2P_LEVEL"] = "PHB" # Set the P2P level to "PHB" (PCIe Host Bridge) for optimal GPU communication on a single instance
os.environ["TOKENIZERS_PARALLELISM"] = "false" # Disable parallelism in tokenizers to avoid potential issues with multiprocessing
import warnings
warnings.filterwarnings("ignore")

# %%
# !rm -rf ckpt #remove checkpoint directory if it already exists to avoid conflicts with previous runs
# !rm -rf logs #remove logs directory if it already exists to avoid conflicts with previous runs

# %%
import configparser
config = configparser.ConfigParser()
config.read("experiment.cfg")
exp = config["experiment"]

DATASET_ROOT = exp["DATASET_ROOT"]
DATASET_REPO = exp["DATASET_REPO"]
POLICY_REPO = exp["POLICY_REPO"]
OUTPUT_DIR = exp["OUTPUT_DIR"]
JOB_NAME = exp["JOB_NAME"] + datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
MAX_TRAIN_STEPS = int(exp["MAX_TRAIN_STEPS"])
CHUNK_SIZE = int(exp["CHUNK_SIZE"])
ACTION_STEPS = int(exp["ACTION_STEPS"])
BATCH_SIZE = int(exp["BATCH_SIZE"])

# %%
#--dataset.root={DATASET_ROOT} \
# !hf download {DATASET_REPO} --repo-type dataset --local-dir {DATASET_ROOT}
# Out:
# Fetching 43 files: 100%|██████████████████████| 43/43 [00:00<00:00, 2534.11it/s]
# /mnt/content/clr_ws/src/vla/Lerobot-Mujoco/dataset/clr_teleoperation_dataset

# %%
# Train the policy pi05 with the specified configuration. The model will be pushed to the Hugging Face Hub under the provided POLICY_REPO name after training.
# !accelerate launch \
--multi_gpu \
--num_machines=1 \
--num_processes=4 \
--mixed_precision=bf16 \
$(which lerobot-train) \
    --dataset.repo_id={DATASET_REPO} \
    --dataset.root={DATASET_ROOT} \
    --policy.type=pi05 \
    --policy.push_to_hub=true \
    --policy.repo_id={POLICY_REPO} \
    --output_dir={OUTPUT_DIR} \
    --job_name={JOB_NAME} \
    --policy.pretrained_path=lerobot/pi05_base \
    --policy.compile_model=false \
    --policy.gradient_checkpointing=true \
    --wandb.enable=true \
    --policy.dtype=bfloat16 \
    --policy.freeze_vision_encoder=false \
    --policy.train_expert_only=false \
    --steps={MAX_TRAIN_STEPS} \
    --log_freq=50 \
    --eval_freq=-1 \
    --policy.device=cuda \
    --policy.chunk_size={CHUNK_SIZE} \
    --policy.n_action_steps={ACTION_STEPS} \
    --batch_size={BATCH_SIZE}
# Out:
# INFO 2026-04-02 17:49:57 ot_train.py:274 {'batch_size': 32,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'gimarchetti/clr-experiment-dataset',
#              'revision': None,
#              'root': './dataset/clr_teleoperation_dataset',
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': -1,
#  'job_name': 'clr-experiment-pi052026-04-02_17-49-50',
#  'log_freq': 50,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.95],
#                'eps': 1e-08,
#                'grad_clip_norm': 1.0,
#                'lr': 2.5e-05,
#                'type': 'adamw',
#                'weight_decay': 0.01},
#  'output_dir': 'ckpt/clr-experiment-pi05',
#  'peft': None,
#  'policy': {'action_expert_variant': 'gemma_300m',
#             'chunk_size': 30,
#             'compile_mode': 'max-autotune',
#             'compile_model': False,
#             'device': 'cuda',
#             'dtype': 'bfloat16',
#             'empty_cameras': 0,
#             'freeze_vision_encoder': False,
#             'gradient_checkpointing': True,
#             'image_resolution': [224, 224],
#             'input_features': {},
#             'license': None,
#             'max_action_dim': 32,
#             'max_period': 4.0,
#             'max_state_dim': 32,
#             'min_period': 0.004,
#             'n_action_steps': 15,
#             'n_obs_steps': 1,
#             'normalization_mapping': {'ACTION': <NormalizationMode.QUANTILES: 'QUANTILES'>,
#                                       'STATE': <NormalizationMode.QUANTILES: 'QUANTILES'>,
#                                       'VISUAL': <NormalizationMode.IDENTITY: 'IDENTITY'>},
#             'num_inference_steps': 10,
#             'optimizer_betas': [0.9, 0.95],
#             'optimizer_eps': 1e-08,
#             'optimizer_grad_clip_norm': 1.0,
#             'optimizer_lr': 2.5e-05,
#             'optimizer_weight_decay': 0.01,
#             'output_features': {},
#             'paligemma_variant': 'gemma_2b',
#             'pretrained_path': 'lerobot/pi05_base',
#             'private': None,
#             'push_to_hub': True,
#             'repo_id': 'gimarchetti/clr-experiment-pi05',
#             'rtc_config': None,
#             'scheduler_decay_lr': 2.5e-06,
#             'scheduler_decay_steps': 30000,
#             'scheduler_warmup_steps': 1000,
#             'tags': None,
#             'time_sampling_beta_alpha': 1.5,
#             'time_sampling_beta_beta': 1.0,
#             'time_sampling_offset': 0.001,
#             'time_sampling_scale': 0.999,
#             'tokenizer_max_length': 200,
#             'train_expert_only': False,
#             'type': 'pi05',
#             'use_amp': False,
#             'use_peft': False},
#  'rabc_epsilon': 1e-06,
#  'rabc_head_mode': 'sparse',
#  'rabc_kappa': 0.01,
#  'rabc_progress_path': None,
#  'rename_map': {},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 20000,
#  'scheduler': {'decay_lr': 2.5e-06,
#                'num_decay_steps': 30000,
#                'num_warmup_steps': 1000,
#                'peak_lr': 2.5e-05,
#                'type': 'cosine_decay_with_warmup'},
#  'seed': 1000,
#  'steps': 2000,
#  'tolerance_s': 0.0001,
#  'use_policy_training_preset': True,
#  'use_rabc': False,
#  'wandb': {'disable_artifact': False,
#            'enable': True,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# /home/gimarchetti_google_com/miniconda3/envs/mujoco2/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /home/gimarchetti_google_com/miniconda3/envs/mujoco2/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# INFO 2026-04-02 17:49:58 db_utils.py:102 Logs will be synced with wandb.
# INFO 2026-04-02 17:49:58 db_utils.py:103 Track this run --> https://wandb.ai/gimarchetti-google/lerobot/runs/i20499my
# INFO 2026-04-02 17:49:58 ot_train.py:294 Creating dataset
# INFO 2026-04-02 17:49:59 ot_train.py:313 Creating policy
# The PI05 model is a direct port of the OpenPI implementation.
# This implementation follows the original OpenPI structure for compatibility.
# Original implementation: https://github.com/Physical-Intelligence/openpi
# The PI05 model is a direct port of the OpenPI implementation.
# This implementation follows the original OpenPI structure for compatibility.
# Original implementation: https://github.com/Physical-Intelligence/openpi
# The PI05 model is a direct port of the OpenPI implementation.
# This implementation follows the original OpenPI structure for compatibility.
# Original implementation: https://github.com/Physical-Intelligence/openpi
# The PI05 model is a direct port of the OpenPI implementation.
# This implementation follows the original OpenPI structure for compatibility.
# Original implementation: https://github.com/Physical-Intelligence/openpi
# INFO 2026-04-02 17:50:25 ing_pi05.py:592 Enabled gradient checkpointing for PI05Pytorch model
# Loading model from: lerobot/pi05_base
# ✓ Loaded state dict from model.safetensors
# WARNING 2026-04-02 17:50:25 ng_pi05.py:1099 Vision embedding key might need handling: paligemma_with_expert.paligemma.model.vision_tower.vision_model.embeddings.patch_embedding.bias
# WARNING 2026-04-02 17:50:25 ng_pi05.py:1099 Vision embedding key might need handling: paligemma_with_expert.paligemma.model.vision_tower.vision_model.embeddings.patch_embedding.weight
# Remapped: action_in_proj.bias -> model.action_in_proj.bias
# Remapped: action_in_proj.weight -> model.action_in_proj.weight
# Remapped: action_out_proj.bias -> model.action_out_proj.bias
# Remapped: action_out_proj.weight -> model.action_out_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.lm_head.weight -> model.paligemma_with_expert.gemma_expert.lm_head.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight
# Remapped 812 state dict keys
# Loading model from: lerobot/pi05_base
# Loading model from: lerobot/pi05_base
# Loading model from: lerobot/pi05_base
# ✓ Loaded state dict from model.safetensors
# Remapped: action_in_proj.bias -> model.action_in_proj.bias
# Remapped: action_in_proj.weight -> model.action_in_proj.weight
# Remapped: action_out_proj.bias -> model.action_out_proj.bias
# Remapped: action_out_proj.weight -> model.action_out_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.lm_head.weight -> model.paligemma_with_expert.gemma_expert.lm_head.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight
# Remapped 812 state dict keys
# ✓ Loaded state dict from model.safetensors
# Remapped: action_in_proj.bias -> model.action_in_proj.bias
# Remapped: action_in_proj.weight -> model.action_in_proj.weight
# Remapped: action_out_proj.bias -> model.action_out_proj.bias
# Remapped: action_out_proj.weight -> model.action_out_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.lm_head.weight -> model.paligemma_with_expert.gemma_expert.lm_head.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight
# Remapped 812 state dict keys
# ✓ Loaded state dict from model.safetensors
# Remapped: action_in_proj.bias -> model.action_in_proj.bias
# Remapped: action_in_proj.weight -> model.action_in_proj.weight
# Remapped: action_out_proj.bias -> model.action_out_proj.bias
# Remapped: action_out_proj.weight -> model.action_out_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.lm_head.weight -> model.paligemma_with_expert.gemma_expert.lm_head.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight
# Remapped 812 state dict keys
# Warning: Could not remap state dict keys: Error(s) in loading state_dict for PI05Policy:
# 	Missing key(s) in state_dict: "model.paligemma_with_expert.paligemma.model.language_model.embed_tokens.weight".
# Warning: Could not remap state dict keys: Error(s) in loading state_dict for PI05Policy:
# 	Missing key(s) in state_dict: "model.paligemma_with_expert.paligemma.model.language_model.embed_tokens.weight".
# Warning: Could not remap state dict keys: Error(s) in loading state_dict for PI05Policy:
# 	Missing key(s) in state_dict: "model.paligemma_with_expert.paligemma.model.language_model.embed_tokens.weight".
# Warning: Could not remap state dict keys: Error(s) in loading state_dict for PI05Policy:
# 	Missing key(s) in state_dict: "model.paligemma_with_expert.paligemma.model.language_model.embed_tokens.weight".
# INFO 2026-04-02 17:50:27 ot_train.py:366 Creating optimizer and scheduler
# INFO 2026-04-02 17:50:27 hedulers.py:105 Auto-scaling LR scheduler: num_training_steps (2000) < num_decay_steps (30000). Scaling warmup: 1000 → 66, decay: 30000 → 2000 (scale factor: 0.067)
# INFO 2026-04-02 17:50:27 ot_train.py:401 Output dir: ckpt/clr-experiment-pi05
# INFO 2026-04-02 17:50:27 ot_train.py:408 cfg.steps=2000 (2K)
# INFO 2026-04-02 17:50:27 ot_train.py:409 dataset.num_frames=23237 (23K)
# INFO 2026-04-02 17:50:27 ot_train.py:410 dataset.num_episodes=50
# INFO 2026-04-02 17:50:27 ot_train.py:413 Effective batch size: 32 x 4 = 128
# INFO 2026-04-02 17:50:27 ot_train.py:414 num_learnable_params=3616757520 (4B)
# INFO 2026-04-02 17:50:27 ot_train.py:415 num_total_params=3616757520 (4B)
# INFO 2026-04-02 17:50:28 ot_train.py:471 Start offline training on a fixed dataset, with effective batch size: 128
# INFO 2026-04-02 17:54:23 ot_train.py:501 step:50 smpl:26K ep:55 epch:1.10 loss:0.125 grdn:1.024 lr:9.9e-06 updt_s:4.677 data_s:0.024
# WARNING 2026-04-02 17:54:23 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 17:58:15 ot_train.py:501 step:100 smpl:51K ep:110 epch:2.20 loss:0.060 grdn:0.439 lr:2.4e-05 updt_s:4.628 data_s:0.006
# WARNING 2026-04-02 17:58:15 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 18:02:07 ot_train.py:501 step:150 smpl:77K ep:165 epch:3.31 loss:0.041 grdn:0.409 lr:2.5e-05 updt_s:4.637 data_s:0.006
# WARNING 2026-04-02 18:02:07 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 18:06:00 ot_train.py:501 step:200 smpl:102K ep:220 epch:4.41 loss:0.034 grdn:0.387 lr:2.5e-05 updt_s:4.644 data_s:0.018
# WARNING 2026-04-02 18:06:00 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 18:09:53 ot_train.py:501 step:250 smpl:128K ep:275 epch:5.51 loss:0.032 grdn:0.376 lr:2.4e-05 updt_s:4.639 data_s:0.007
# WARNING 2026-04-02 18:09:53 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 18:13:45 ot_train.py:501 step:300 smpl:154K ep:331 epch:6.61 loss:0.027 grdn:0.370 lr:2.4e-05 updt_s:4.636 data_s:0.008
# WARNING 2026-04-02 18:13:45 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 18:17:37 ot_train.py:501 step:350 smpl:179K ep:386 epch:7.71 loss:0.025 grdn:0.368 lr:2.4e-05 updt_s:4.630 data_s:0.008
# WARNING 2026-04-02 18:17:37 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 18:21:31 ot_train.py:501 step:400 smpl:205K ep:441 epch:8.81 loss:0.023 grdn:0.345 lr:2.3e-05 updt_s:4.654 data_s:0.019
# WARNING 2026-04-02 18:21:31 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 18:25:23 ot_train.py:501 step:450 smpl:230K ep:496 epch:9.92 loss:0.021 grdn:0.352 lr:2.3e-05 updt_s:4.641 data_s:0.008
# WARNING 2026-04-02 18:25:23 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 18:29:16 ot_train.py:501 step:500 smpl:256K ep:551 epch:11.02 loss:0.021 grdn:0.343 lr:2.2e-05 updt_s:4.644 data_s:0.006
# WARNING 2026-04-02 18:29:16 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 18:33:10 ot_train.py:501 step:550 smpl:282K ep:606 epch:12.12 loss:0.021 grdn:0.367 lr:2.1e-05 updt_s:4.654 data_s:0.018
# WARNING 2026-04-02 18:33:10 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 18:37:03 ot_train.py:501 step:600 smpl:307K ep:661 epch:13.22 loss:0.019 grdn:0.350 lr:2.1e-05 updt_s:4.645 data_s:0.007
# WARNING 2026-04-02 18:37:03 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 18:40:56 ot_train.py:501 step:650 smpl:333K ep:716 epch:14.32 loss:0.019 grdn:0.343 lr:2.0e-05 updt_s:4.656 data_s:0.008
# WARNING 2026-04-02 18:40:56 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 18:44:49 ot_train.py:501 step:700 smpl:358K ep:771 epch:15.42 loss:0.018 grdn:0.355 lr:1.9e-05 updt_s:4.644 data_s:0.007
# WARNING 2026-04-02 18:44:49 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 18:48:43 ot_train.py:501 step:750 smpl:384K ep:826 epch:16.53 loss:0.016 grdn:0.342 lr:1.8e-05 updt_s:4.654 data_s:0.018
# WARNING 2026-04-02 18:48:43 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 18:52:35 ot_train.py:501 step:800 smpl:410K ep:881 epch:17.63 loss:0.016 grdn:0.339 lr:1.8e-05 updt_s:4.644 data_s:0.007
# WARNING 2026-04-02 18:52:35 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 18:56:28 ot_train.py:501 step:850 smpl:435K ep:936 epch:18.73 loss:0.016 grdn:0.327 lr:1.7e-05 updt_s:4.643 data_s:0.007
# WARNING 2026-04-02 18:56:28 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:00:21 ot_train.py:501 step:900 smpl:461K ep:992 epch:19.83 loss:0.015 grdn:0.318 lr:1.6e-05 updt_s:4.651 data_s:0.007
# WARNING 2026-04-02 19:00:21 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:04:15 ot_train.py:501 step:950 smpl:486K ep:1K epch:20.93 loss:0.015 grdn:0.334 lr:1.5e-05 updt_s:4.656 data_s:0.019
# WARNING 2026-04-02 19:04:15 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:08:08 ot_train.py:501 step:1K smpl:512K ep:1K epch:22.03 loss:0.014 grdn:0.317 lr:1.4e-05 updt_s:4.651 data_s:0.007
# WARNING 2026-04-02 19:08:08 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:12:01 ot_train.py:501 step:1K smpl:538K ep:1K epch:23.14 loss:0.013 grdn:0.322 lr:1.3e-05 updt_s:4.648 data_s:0.006
# WARNING 2026-04-02 19:12:01 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:15:55 ot_train.py:501 step:1K smpl:563K ep:1K epch:24.24 loss:0.013 grdn:0.316 lr:1.2e-05 updt_s:4.660 data_s:0.017
# WARNING 2026-04-02 19:15:55 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:19:48 ot_train.py:501 step:1K smpl:589K ep:1K epch:25.34 loss:0.013 grdn:0.291 lr:1.2e-05 updt_s:4.643 data_s:0.007
# WARNING 2026-04-02 19:19:48 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:23:41 ot_train.py:501 step:1K smpl:614K ep:1K epch:26.44 loss:0.013 grdn:0.308 lr:1.1e-05 updt_s:4.653 data_s:0.007
# WARNING 2026-04-02 19:23:41 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:27:34 ot_train.py:501 step:1K smpl:640K ep:1K epch:27.54 loss:0.012 grdn:0.307 lr:9.8e-06 updt_s:4.646 data_s:0.008
# WARNING 2026-04-02 19:27:34 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:31:27 ot_train.py:501 step:1K smpl:666K ep:1K epch:28.64 loss:0.013 grdn:0.310 lr:9.0e-06 updt_s:4.648 data_s:0.017
# WARNING 2026-04-02 19:31:27 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:35:20 ot_train.py:501 step:1K smpl:691K ep:1K epch:29.75 loss:0.012 grdn:0.299 lr:8.2e-06 updt_s:4.645 data_s:0.006
# WARNING 2026-04-02 19:35:20 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:39:13 ot_train.py:501 step:1K smpl:717K ep:2K epch:30.85 loss:0.012 grdn:0.304 lr:7.5e-06 updt_s:4.649 data_s:0.008
# WARNING 2026-04-02 19:39:13 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:43:05 ot_train.py:501 step:1K smpl:742K ep:2K epch:31.95 loss:0.012 grdn:0.301 lr:6.8e-06 updt_s:4.640 data_s:0.008
# WARNING 2026-04-02 19:43:05 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:46:59 ot_train.py:501 step:2K smpl:768K ep:2K epch:33.05 loss:0.012 grdn:0.304 lr:6.1e-06 updt_s:4.646 data_s:0.017
# WARNING 2026-04-02 19:46:59 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:50:51 ot_train.py:501 step:2K smpl:794K ep:2K epch:34.15 loss:0.011 grdn:0.309 lr:5.5e-06 updt_s:4.641 data_s:0.006
# WARNING 2026-04-02 19:50:51 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:54:44 ot_train.py:501 step:2K smpl:819K ep:2K epch:35.25 loss:0.012 grdn:0.301 lr:4.9e-06 updt_s:4.651 data_s:0.007
# WARNING 2026-04-02 19:54:44 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 19:58:38 ot_train.py:501 step:2K smpl:845K ep:2K epch:36.36 loss:0.011 grdn:0.293 lr:4.4e-06 updt_s:4.651 data_s:0.017
# WARNING 2026-04-02 19:58:38 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 20:02:31 ot_train.py:501 step:2K smpl:870K ep:2K epch:37.46 loss:0.012 grdn:0.295 lr:3.9e-06 updt_s:4.647 data_s:0.007
# WARNING 2026-04-02 20:02:31 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 20:06:23 ot_train.py:501 step:2K smpl:896K ep:2K epch:38.56 loss:0.010 grdn:0.295 lr:3.5e-06 updt_s:4.639 data_s:0.007
# WARNING 2026-04-02 20:06:23 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 20:10:16 ot_train.py:501 step:2K smpl:922K ep:2K epch:39.66 loss:0.012 grdn:0.299 lr:3.2e-06 updt_s:4.641 data_s:0.008
# WARNING 2026-04-02 20:10:16 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 20:14:10 ot_train.py:501 step:2K smpl:947K ep:2K epch:40.76 loss:0.010 grdn:0.291 lr:2.9e-06 updt_s:4.658 data_s:0.022
# WARNING 2026-04-02 20:14:10 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 20:18:03 ot_train.py:501 step:2K smpl:973K ep:2K epch:41.86 loss:0.012 grdn:0.309 lr:2.7e-06 updt_s:4.644 data_s:0.007
# WARNING 2026-04-02 20:18:03 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 20:21:56 ot_train.py:501 step:2K smpl:998K ep:2K epch:42.97 loss:0.010 grdn:0.283 lr:2.6e-06 updt_s:4.647 data_s:0.008
# WARNING 2026-04-02 20:21:56 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 20:25:49 ot_train.py:501 step:2K smpl:1M ep:2K epch:44.07 loss:0.010 grdn:0.297 lr:2.5e-06 updt_s:4.656 data_s:0.008
# WARNING 2026-04-02 20:25:49 db_utils.py:166 WandB logging of key "loss_per_dim" was ignored as its type "<class 'list'>" is not handled by this wrapper.
# INFO 2026-04-02 20:25:49 ot_train.py:521 Checkpoint policy after step 2000
# INFO 2026-04-02 20:26:18 ot_train.py:592 End of training
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...nt-pi05/model.safetensors:   0%|              |  131kB / 7.47GB
#
# Processing Files (0 / 1)      :   0%|              |  131kB / 7.47GB,   ???B/s
#
#   ...nt-pi05/model.safetensors:   0%|              |  131kB / 7.47GB
#
#   ...nt-pi05/model.safetensors:   0%|              |  131kB / 7.47GB
#
# Processing Files (0 / 1)      :   0%|              |  687kB / 7.47GB,  927kB/s
# New Data Upload               :   1%|              |  556kB / 67.1MB,  927kB/s
#
# Processing Files (0 / 1)      :   0%|              | 3.47MB / 7.47GB, 4.17MB/s
# New Data Upload               :   2%|▎             | 3.34MB /  134MB, 4.17MB/s
#
# Processing Files (0 / 1)      :   0%|              | 10.7MB / 7.47GB, 10.6MB/s
# New Data Upload               :   8%|█             | 10.6MB /  134MB, 10.6MB/s
#
# Processing Files (0 / 1)      :   0%|              | 21.8MB / 7.47GB, 18.1MB/s
# New Data Upload               :  16%|██▎           | 21.7MB /  134MB, 18.1MB/s
#
# Processing Files (0 / 1)      :   0%|              | 29.1MB / 7.47GB, 20.7MB/s
# New Data Upload               :  22%|███           | 28.9MB /  134MB, 20.7MB/s
#
# Processing Files (0 / 1)      :   1%|              | 40.8MB / 7.47GB, 25.4MB/s
# New Data Upload               :  30%|████▏         | 40.6MB /  134MB, 25.4MB/s
#
# Processing Files (0 / 1)      :   1%|              | 50.8MB / 7.47GB, 28.1MB/s
# New Data Upload               :  38%|█████▎        | 50.6MB /  134MB, 28.1MB/s
#
# Processing Files (0 / 1)      :   1%|              | 61.9MB / 7.47GB, 30.9MB/s
# New Data Upload               :  46%|██████▍       | 61.8MB /  134MB, 30.9MB/s
#
# Processing Files (0 / 1)      :   1%|▏             | 66.9MB / 7.47GB, 30.4MB/s
# New Data Upload               :  50%|██████▉       | 66.8MB /  134MB, 30.4MB/s
#
#   ...nt-pi05/model.safetensors:   1%|▏             | 66.9MB / 7.47GB
#
#   ...nt-pi05/model.safetensors:   1%|▏             | 66.9MB / 7.47GB
#
#   ...nt-pi05/model.safetensors:   1%|▏             | 66.9MB / 7.47GB
#
# Processing Files (0 / 1)      :   1%|▏             | 71.1MB / 7.47GB, 23.7MB/s
# New Data Upload               :  53%|███████▍      | 71.0MB /  134MB, 23.7MB/s
#
# Processing Files (0 / 1)      :   1%|▏             | 76.7MB / 7.47GB, 23.9MB/s
# New Data Upload               :  38%|█████▎        | 76.5MB /  201MB, 23.9MB/s
#
# Processing Files (0 / 1)      :   1%|▏             | 86.7MB / 7.47GB, 25.4MB/s
# New Data Upload               :  32%|████▌         | 86.5MB /  268MB, 25.4MB/s
#
# Processing Files (0 / 1)      :   1%|▏             |  101MB / 7.47GB, 28.0MB/s
# New Data Upload               :  38%|█████▎        |  101MB /  268MB, 28.0MB/s
#
# Processing Files (0 / 1)      :   2%|▏             |  115MB / 7.47GB, 30.2MB/s
# New Data Upload               :  43%|█████▉        |  115MB /  268MB, 30.2MB/s
#
# Processing Files (0 / 1)      :   2%|▏             |  131MB / 7.47GB, 32.6MB/s
# New Data Upload               :  39%|█████▍        |  130MB /  335MB, 32.6MB/s
#
# Processing Files (0 / 1)      :   2%|▎             |  149MB / 7.47GB, 35.4MB/s
# New Data Upload               :  44%|██████▏       |  149MB /  335MB, 35.4MB/s
#
# Processing Files (0 / 1)      :   2%|▎             |  173MB / 7.47GB, 39.3MB/s
# New Data Upload               :  43%|██████        |  173MB /  402MB, 39.3MB/s
#
# Processing Files (0 / 1)      :   3%|▎             |  195MB / 7.47GB, 42.4MB/s
# New Data Upload               :  48%|██████▊       |  195MB /  402MB, 42.4MB/s
#
# Processing Files (0 / 1)      :   3%|▍             |  229MB / 7.47GB, 47.7MB/s
# New Data Upload               :  48%|██████▋       |  225MB /  470MB, 46.9MB/s
#
# Processing Files (0 / 1)      :   4%|▍             |  262MB / 7.47GB, 52.4MB/s
# New Data Upload               :  55%|███████▋      |  258MB /  470MB, 51.6MB/s
#
# Processing Files (0 / 1)      :   5%|▋             |  365MB / 7.47GB, 70.1MB/s
# New Data Upload               :  63%|████████▊     |  295MB /  470MB, 56.8MB/s
#
# Processing Files (0 / 1)      :   7%|▉             |  499MB / 7.47GB, 92.4MB/s
# New Data Upload               :  71%|█████████▉    |  334MB /  470MB, 61.8MB/s
#
# Processing Files (0 / 1)      :   8%|█▏            |  614MB / 7.47GB,  110MB/s
# New Data Upload               :  77%|██████████▊   |  361MB /  470MB, 64.5MB/s
#
# Processing Files (0 / 1)      :  10%|█▎            |  729MB / 7.47GB,  126MB/s
# New Data Upload               :  81%|███████████▎  |  380MB /  470MB, 65.5MB/s
#
# Processing Files (0 / 1)      :  11%|█▌            |  839MB / 7.47GB,  140MB/s
# New Data Upload               :  86%|███████████▉  |  402MB /  470MB, 66.9MB/s
#
# Processing Files (0 / 1)      :  13%|█▊            |  950MB / 7.47GB,  153MB/s
# New Data Upload               :  89%|████████████▍ |  419MB /  470MB, 67.5MB/s
#
# Processing Files (0 / 1)      :  13%|█▊            |  959MB / 7.47GB,  150MB/s
# New Data Upload               :  80%|███████████▏  |  429MB /  537MB, 67.0MB/s
#
# Processing Files (0 / 1)      :  13%|█▊            |  971MB / 7.47GB,  147MB/s
# New Data Upload               :  73%|██████████▏   |  441MB /  604MB, 66.7MB/s
#
# Processing Files (0 / 1)      :  13%|█▊            |  996MB / 7.47GB,  146MB/s
# New Data Upload               :  77%|██████████▊   |  465MB /  604MB, 68.4MB/s
#
# Processing Files (0 / 1)      :  14%|█▉            | 1.02GB / 7.47GB,  145MB/s
# New Data Upload               :  73%|██████████▏   |  487MB /  671MB, 69.6MB/s
#
# Processing Files (0 / 1)      :  14%|█▉            | 1.05GB / 7.47GB,  146MB/s
# New Data Upload               :  77%|██████████▊   |  518MB /  671MB, 71.9MB/s
#
# Processing Files (0 / 1)      :  15%|██            | 1.09GB / 7.47GB,  148MB/s
# New Data Upload               :  76%|██████████▋   |  564MB /  738MB, 76.2MB/s
#
# Processing Files (0 / 1)      :  15%|██▏           | 1.14GB / 7.47GB,  149MB/s
# New Data Upload               :  75%|██████████▌   |  605MB /  805MB, 79.6MB/s
#
# Processing Files (0 / 1)      :  16%|██▏           | 1.18GB / 7.47GB,  151MB/s
# New Data Upload               :  81%|███████████▎  |  649MB /  805MB, 83.2MB/s
#
# Processing Files (0 / 1)      :  16%|██▎           | 1.23GB / 7.47GB,  153MB/s
# New Data Upload               :  80%|███████████▏  |  695MB /  872MB, 86.8MB/s
#
# Processing Files (0 / 1)      :  17%|██▎           | 1.25GB / 7.47GB,  153MB/s
# New Data Upload               :  77%|██████████▋   |  720MB /  939MB, 87.8MB/s
#
# Processing Files (0 / 1)      :  17%|██▍           | 1.28GB / 7.47GB,  152MB/s
# New Data Upload               :  79%|███████████   |  745MB /  939MB, 88.6MB/s
#
# Processing Files (0 / 1)      :  17%|██▍           | 1.30GB / 7.47GB,  151MB/s
# New Data Upload               :  82%|███████████▍  |  769MB /  939MB, 89.4MB/s
#
# Processing Files (0 / 1)      :  18%|██▍           | 1.32GB / 7.47GB,  150MB/s
# New Data Upload               :  79%|███████████   |  791MB / 1.01GB, 89.9MB/s
#
# Processing Files (0 / 1)      :  18%|██▌           | 1.36GB / 7.47GB,  151MB/s
# New Data Upload               :  77%|██████████▊   |  825MB / 1.07GB, 91.7MB/s
#
# Processing Files (0 / 1)      :  20%|██▊           | 1.48GB / 7.47GB,  161MB/s
# New Data Upload               :  80%|███████████▏  |  861MB / 1.07GB, 93.6MB/s
#
# Processing Files (0 / 1)      :  22%|███           | 1.62GB / 7.47GB,  172MB/s
# New Data Upload               :  85%|███████████▊  |  910MB / 1.07GB, 96.8MB/s
#
# Processing Files (0 / 1)      :  24%|███▎          | 1.76GB / 7.47GB,  183MB/s
# New Data Upload               :  89%|████████████▍ |  956MB / 1.07GB, 99.6MB/s
#
# Processing Files (0 / 1)      :  25%|███▌          | 1.88GB / 7.47GB,  192MB/s
# New Data Upload               :  92%|████████████▉ |  990MB / 1.07GB,  101MB/s
#
# Processing Files (0 / 1)      :  27%|███▊          | 2.00GB / 7.47GB,  200MB/s
# New Data Upload               :  94%|█████████████▏| 1.01GB / 1.07GB,  101MB/s
#
# Processing Files (0 / 1)      :  28%|███▉          | 2.11GB / 7.47GB,  207MB/s
# New Data Upload               :  96%|█████████████▍| 1.03GB / 1.07GB,  101MB/s
#
# Processing Files (0 / 1)      :  30%|████▏         | 2.21GB / 7.47GB,  217MB/s
# New Data Upload               :  97%|█████████████▌| 1.04GB / 1.07GB,  102MB/s
#
# Processing Files (0 / 1)      :  31%|████▎         | 2.31GB / 7.47GB,  227MB/s
# New Data Upload               :  98%|█████████████▋| 1.05GB / 1.07GB,  103MB/s
#
# Processing Files (0 / 1)      :  32%|████▌         | 2.41GB / 7.47GB,  236MB/s
# New Data Upload               :  99%|█████████████▊| 1.06GB / 1.07GB,  104MB/s
#
# Processing Files (0 / 1)      :  34%|████▋         | 2.51GB / 7.47GB,  246MB/s
# New Data Upload               :  99%|█████████████▉| 1.07GB / 1.07GB,  104MB/s
#
# Processing Files (0 / 1)      :  35%|████▉         | 2.60GB / 7.47GB,  254MB/s
# New Data Upload               : 100%|█████████████▉| 1.07GB / 1.07GB,  104MB/s
#
# Processing Files (0 / 1)      :  36%|████▉         | 2.65GB / 7.47GB,  258MB/s
# New Data Upload               :  94%|█████████████▏| 1.07GB / 1.14GB,  103MB/s
#
# Processing Files (0 / 1)      :  36%|████▉         | 2.66GB / 7.47GB,  258MB/s
# New Data Upload               :  94%|█████████████▏| 1.08GB / 1.14GB,  103MB/s
#
# Processing Files (0 / 1)      :  36%|████▉         | 2.66GB / 7.47GB,  257MB/s
# New Data Upload               :  90%|████████████▌ | 1.08GB / 1.21GB,  102MB/s
#
# Processing Files (0 / 1)      :  36%|█████         | 2.68GB / 7.47GB,  258MB/s
# New Data Upload               :  86%|████████████  | 1.10GB / 1.27GB,  103MB/s
#
# Processing Files (0 / 1)      :  36%|█████         | 2.70GB / 7.47GB,  259MB/s
# New Data Upload               :  83%|███████████▋  | 1.12GB / 1.34GB,  104MB/s
#
# Processing Files (0 / 1)      :  36%|█████         | 2.72GB / 7.47GB,  260MB/s
# New Data Upload               :  85%|███████████▉  | 1.14GB / 1.34GB,  105MB/s
#
# Processing Files (0 / 1)      :  37%|█████▏        | 2.76GB / 7.47GB,  264MB/s
# New Data Upload               :  83%|███████████▋  | 1.18GB / 1.41GB,  109MB/s
#
# Processing Files (0 / 1)      :  37%|█████▏        | 2.78GB / 7.47GB,  266MB/s
# New Data Upload               :  81%|███████████▍  | 1.20GB / 1.48GB,  111MB/s
#
# Processing Files (0 / 1)      :  38%|█████▎        | 2.81GB / 7.47GB,  269MB/s
# New Data Upload               :  80%|███████████▏  | 1.23GB / 1.54GB,  114MB/s
#
# Processing Files (0 / 1)      :  38%|█████▎        | 2.85GB / 7.47GB,  272MB/s
# New Data Upload               :  79%|███████████   | 1.27GB / 1.61GB,  117MB/s
#
# Processing Files (0 / 1)      :  39%|█████▍        | 2.90GB / 7.47GB,  277MB/s
# New Data Upload               :  82%|███████████▍  | 1.32GB / 1.61GB,  122MB/s
#
# Processing Files (0 / 1)      :  39%|█████▌        | 2.94GB / 7.47GB,  280MB/s
# New Data Upload               :  84%|███████████▊  | 1.36GB / 1.61GB,  125MB/s
#
# Processing Files (0 / 1)      :  40%|█████▌        | 2.99GB / 7.47GB,  284MB/s
# New Data Upload               :  84%|███████████▊  | 1.41GB / 1.68GB,  129MB/s
#
# Processing Files (0 / 1)      :  41%|█████▋        | 3.06GB / 7.47GB,  289MB/s
# New Data Upload               :  85%|███████████▊  | 1.48GB / 1.74GB,  134MB/s
#
# Processing Files (0 / 1)      :  42%|█████▊        | 3.13GB / 7.47GB,  294MB/s
# New Data Upload               :  89%|████████████▍ | 1.54GB / 1.74GB,  139MB/s
#
# Processing Files (0 / 1)      :  43%|█████▉        | 3.18GB / 7.47GB,  297MB/s
# New Data Upload               :  88%|████████████▍ | 1.60GB / 1.81GB,  142MB/s
#
# Processing Files (0 / 1)      :  43%|██████        | 3.23GB / 7.47GB,  299MB/s
# New Data Upload               :  91%|████████████▋ | 1.65GB / 1.81GB,  144MB/s
#
# Processing Files (0 / 1)      :  44%|██████▏       | 3.27GB / 7.47GB,  302MB/s
# New Data Upload               :  90%|████████████▌ | 1.69GB / 1.88GB,  147MB/s
#
# Processing Files (0 / 1)      :  44%|██████▏       | 3.32GB / 7.47GB,  303MB/s
# New Data Upload               :  89%|████████████▌ | 1.74GB / 1.95GB,  148MB/s
#
# Processing Files (0 / 1)      :  45%|██████▎       | 3.36GB / 7.47GB,  303MB/s
# New Data Upload               :  88%|████████████▎ | 1.78GB / 2.01GB,  149MB/s
#
# Processing Files (0 / 1)      :  46%|██████▍       | 3.41GB / 7.47GB,  298MB/s
# New Data Upload               :  88%|████████████▎ | 1.83GB / 2.08GB,  150MB/s
#
# Processing Files (0 / 1)      :  46%|██████▍       | 3.46GB / 7.47GB,  290MB/s
# New Data Upload               :  88%|████████████▎ | 1.88GB / 2.15GB,  151MB/s
#
# Processing Files (0 / 1)      :  47%|██████▌       | 3.51GB / 7.47GB,  284MB/s
# New Data Upload               :  90%|████████████▌ | 1.93GB / 2.15GB,  154MB/s
#
# Processing Files (0 / 1)      :  48%|██████▋       | 3.56GB / 7.47GB,  278MB/s
# New Data Upload               :  90%|████████████▌ | 1.98GB / 2.21GB,  157MB/s
#
# Processing Files (0 / 1)      :  48%|██████▊       | 3.61GB / 7.47GB,  272MB/s
# New Data Upload               :  89%|████████████▍ | 2.03GB / 2.28GB,  160MB/s
#
# Processing Files (0 / 1)      :  49%|██████▊       | 3.66GB / 7.47GB,  266MB/s
# New Data Upload               :  89%|████████████▍ | 2.08GB / 2.35GB,  163MB/s
#
# Processing Files (0 / 1)      :  50%|██████▉       | 3.73GB / 7.47GB,  272MB/s
# New Data Upload               :  92%|████████████▊ | 2.15GB / 2.35GB,  169MB/s
#
# Processing Files (0 / 1)      :  51%|███████       | 3.78GB / 7.47GB,  275MB/s
# New Data Upload               :  91%|████████████▊ | 2.20GB / 2.41GB,  172MB/s
#
# Processing Files (0 / 1)      :  51%|███████▏      | 3.84GB / 7.47GB,  279MB/s
# New Data Upload               :  91%|████████████▋ | 2.26GB / 2.48GB,  176MB/s
#
# Processing Files (0 / 1)      :  52%|███████▎      | 3.89GB / 7.47GB,  282MB/s
# New Data Upload               :  91%|████████████▋ | 2.31GB / 2.55GB,  179MB/s
#
# Processing Files (0 / 1)      :  53%|███████▍      | 3.95GB / 7.47GB,  285MB/s
# New Data Upload               :  91%|████████████▋ | 2.37GB / 2.62GB,  182MB/s
#
# Processing Files (0 / 1)      :  54%|███████▌      | 4.00GB / 7.47GB,  285MB/s
# New Data Upload               :  93%|████████████▉ | 2.42GB / 2.62GB,  182MB/s
#
# Processing Files (0 / 1)      :  54%|███████▌      | 4.05GB / 7.47GB,  286MB/s
# New Data Upload               :  92%|████████████▉ | 2.47GB / 2.68GB,  183MB/s
#
# Processing Files (0 / 1)      :  55%|███████▋      | 4.09GB / 7.47GB,  285MB/s
# New Data Upload               :  93%|█████████████ | 2.51GB / 2.68GB,  182MB/s
#
# Processing Files (0 / 1)      :  55%|███████▋      | 4.13GB / 7.47GB,  285MB/s
# New Data Upload               :  93%|████████████▉ | 2.55GB / 2.75GB,  182MB/s
#
# Processing Files (0 / 1)      :  56%|███████▊      | 4.18GB / 7.47GB,  287MB/s
# New Data Upload               :  92%|████████████▉ | 2.59GB / 2.82GB,  184MB/s
#
# Processing Files (0 / 1)      :  57%|███████▉      | 4.22GB / 7.47GB,  289MB/s
# New Data Upload               :  94%|█████████████▏| 2.64GB / 2.82GB,  186MB/s
#
# Processing Files (0 / 1)      :  57%|████████      | 4.27GB / 7.47GB,  291MB/s
# New Data Upload               :  93%|█████████████ | 2.69GB / 2.88GB,  188MB/s
#
# Processing Files (0 / 1)      :  58%|████████      | 4.32GB / 7.47GB,  294MB/s
# New Data Upload               :  93%|████████████▉ | 2.73GB / 2.95GB,  191MB/s
#
# Processing Files (0 / 1)      :  58%|████████▏     | 4.35GB / 7.47GB,  294MB/s
# New Data Upload               :  94%|█████████████▏| 2.77GB / 2.95GB,  191MB/s
#
# Processing Files (0 / 1)      :  59%|████████▏     | 4.40GB / 7.47GB,  286MB/s
# New Data Upload               :  93%|█████████████ | 2.82GB / 3.02GB,  192MB/s
#
# Processing Files (0 / 1)      :  60%|████████▍     | 4.50GB / 7.47GB,  283MB/s
# New Data Upload               :  95%|█████████████▎| 2.86GB / 3.02GB,  191MB/s
#
# Processing Files (0 / 1)      :  62%|████████▋     | 4.63GB / 7.47GB,  281MB/s
# New Data Upload               :  96%|█████████████▍| 2.89GB / 3.02GB,  190MB/s
#
# Processing Files (0 / 1)      :  63%|████████▊     | 4.71GB / 7.47GB,  277MB/s
# New Data Upload               :  94%|█████████████▏| 2.92GB / 3.09GB,  189MB/s
#
# Processing Files (0 / 1)      :  64%|████████▉     | 4.75GB / 7.47GB,  269MB/s
# New Data Upload               :  96%|█████████████▎| 2.95GB / 3.09GB,  189MB/s
#
# Processing Files (0 / 1)      :  64%|████████▉     | 4.77GB / 7.47GB,  261MB/s
# New Data Upload               :  94%|█████████████▏| 2.97GB / 3.15GB,  190MB/s
#
# Processing Files (0 / 1)      :  64%|████████▉     | 4.80GB / 7.47GB,  254MB/s
# New Data Upload               :  93%|█████████████ | 3.00GB / 3.22GB,  192MB/s
#
# Processing Files (0 / 1)      :  65%|█████████     | 4.84GB / 7.47GB,  248MB/s
# New Data Upload               :  93%|████████████▉ | 3.04GB / 3.29GB,  195MB/s
#
# Processing Files (0 / 1)      :  65%|█████████▏    | 4.89GB / 7.47GB,  244MB/s
# New Data Upload               :  92%|████████████▉ | 3.09GB / 3.35GB,  200MB/s
#
# Processing Files (0 / 1)      :  66%|█████████▎    | 4.94GB / 7.47GB,  239MB/s
# New Data Upload               :  94%|█████████████ | 3.14GB / 3.35GB,  204MB/s
#
# Processing Files (0 / 1)      :  67%|█████████▎    | 5.00GB / 7.47GB,  235MB/s
# New Data Upload               :  93%|█████████████ | 3.20GB / 3.42GB,  208MB/s
#
# Processing Files (0 / 1)      :  67%|█████████▍    | 5.04GB / 7.47GB,  234MB/s
# New Data Upload               :  93%|████████████▉ | 3.24GB / 3.49GB,  212MB/s
#
# Processing Files (0 / 1)      :  68%|█████████▌    | 5.09GB / 7.47GB,  239MB/s
# New Data Upload               :  94%|█████████████▏| 3.29GB / 3.49GB,  217MB/s
#
# Processing Files (0 / 1)      :  69%|█████████▋    | 5.15GB / 7.47GB,  243MB/s
# New Data Upload               :  94%|█████████████▏| 3.35GB / 3.55GB,  222MB/s
#
# Processing Files (0 / 1)      :  70%|█████████▋    | 5.20GB / 7.47GB,  247MB/s
# New Data Upload               :  94%|█████████████▏| 3.40GB / 3.62GB,  226MB/s
#
# Processing Files (0 / 1)      :  70%|█████████▊    | 5.26GB / 7.47GB,  251MB/s
# New Data Upload               :  94%|█████████████▏| 3.46GB / 3.69GB,  230MB/s
#
# Processing Files (0 / 1)      :  71%|█████████▉    | 5.32GB / 7.47GB,  254MB/s
# New Data Upload               :  95%|█████████████▎| 3.52GB / 3.69GB,  233MB/s
#
# Processing Files (0 / 1)      :  72%|██████████    | 5.36GB / 7.47GB,  255MB/s
# New Data Upload               :  95%|█████████████▎| 3.56GB / 3.76GB,  234MB/s
#
# Processing Files (0 / 1)      :  72%|██████████▏   | 5.41GB / 7.47GB,  257MB/s
# New Data Upload               :  96%|█████████████▍| 3.61GB / 3.76GB,  236MB/s
#
# Processing Files (0 / 1)      :  73%|██████████▏   | 5.46GB / 7.47GB,  259MB/s
# New Data Upload               :  96%|█████████████▍| 3.66GB / 3.82GB,  238MB/s
#
# Processing Files (0 / 1)      :  73%|██████████▎   | 5.48GB / 7.47GB,  257MB/s
# New Data Upload               :  95%|█████████████▏| 3.68GB / 3.89GB,  236MB/s
#
# Processing Files (0 / 1)      :  74%|██████████▎   | 5.50GB / 7.47GB,  255MB/s
# New Data Upload               :  95%|█████████████▎| 3.70GB / 3.89GB,  234MB/s
#
# Processing Files (0 / 1)      :  74%|██████████▍   | 5.56GB / 7.47GB,  256MB/s
# New Data Upload               :  95%|█████████████▎| 3.76GB / 3.96GB,  235MB/s
#
# Processing Files (0 / 1)      :  75%|██████████▍   | 5.59GB / 7.47GB,  255MB/s
# New Data Upload               :  94%|█████████████▏| 3.79GB / 4.02GB,  233MB/s
#
# Processing Files (0 / 1)      :  75%|██████████▌   | 5.64GB / 7.47GB,  253MB/s
# New Data Upload               :  94%|█████████████▏| 3.84GB / 4.09GB,  232MB/s
#
# Processing Files (0 / 1)      :  76%|██████████▋   | 5.70GB / 7.47GB,  252MB/s
# New Data Upload               :  95%|█████████████▎| 3.90GB / 4.09GB,  231MB/s
#
# Processing Files (0 / 1)      :  77%|██████████▊   | 5.77GB / 7.47GB,  253MB/s
# New Data Upload               :  95%|█████████████▎| 3.97GB / 4.16GB,  232MB/s
#
# Processing Files (0 / 1)      :  78%|██████████▉   | 5.82GB / 7.47GB,  254MB/s
# New Data Upload               :  95%|█████████████▎| 4.02GB / 4.23GB,  233MB/s
#
# Processing Files (0 / 1)      :  79%|███████████   | 5.88GB / 7.47GB,  256MB/s
# New Data Upload               :  95%|█████████████▎| 4.08GB / 4.29GB,  235MB/s
#
# Processing Files (0 / 1)      :  79%|███████████   | 5.94GB / 7.47GB,  257MB/s
# New Data Upload               :  95%|█████████████▎| 4.14GB / 4.36GB,  235MB/s
#
# Processing Files (0 / 1)      :  80%|███████████▏  | 5.98GB / 7.47GB,  257MB/s
# New Data Upload               :  96%|█████████████▍| 4.18GB / 4.36GB,  236MB/s
#
# Processing Files (0 / 1)      :  80%|███████████▎  | 6.01GB / 7.47GB,  255MB/s
# New Data Upload               :  95%|█████████████▎| 4.22GB / 4.43GB,  234MB/s
#
# Processing Files (0 / 1)      :  81%|███████████▎  | 6.05GB / 7.47GB,  254MB/s
# New Data Upload               :  95%|█████████████▏| 4.25GB / 4.49GB,  233MB/s
#
# Processing Files (0 / 1)      :  81%|███████████▍  | 6.08GB / 7.47GB,  252MB/s
# New Data Upload               :  94%|█████████████▏| 4.29GB / 4.56GB,  231MB/s
#
# Processing Files (0 / 1)      :  82%|███████████▍  | 6.12GB / 7.47GB,  251MB/s
# New Data Upload               :  93%|█████████████ | 4.33GB / 4.63GB,  230MB/s
#
# Processing Files (0 / 1)      :  83%|███████████▌  | 6.18GB / 7.47GB,  252MB/s
# New Data Upload               :  93%|█████████████ | 4.38GB / 4.69GB,  230MB/s
#
# Processing Files (0 / 1)      :  84%|███████████▋  | 6.25GB / 7.47GB,  253MB/s
# New Data Upload               :  95%|█████████████▎| 4.45GB / 4.69GB,  232MB/s
#
# Processing Files (0 / 1)      :  84%|███████████▊  | 6.31GB / 7.47GB,  253MB/s
# New Data Upload               :  95%|█████████████▎| 4.51GB / 4.76GB,  231MB/s
#
# Processing Files (0 / 1)      :  85%|███████████▉  | 6.38GB / 7.47GB,  255MB/s
# New Data Upload               :  95%|█████████████▎| 4.58GB / 4.83GB,  233MB/s
#
# Processing Files (0 / 1)      :  86%|████████████  | 6.45GB / 7.47GB,  256MB/s
# New Data Upload               :  95%|█████████████▎| 4.65GB / 4.90GB,  234MB/s
#
# Processing Files (0 / 1)      :  87%|████████████▏ | 6.52GB / 7.47GB,  258MB/s
# New Data Upload               :  95%|█████████████▎| 4.72GB / 4.96GB,  236MB/s
#
# Processing Files (0 / 1)      :  88%|████████████▎ | 6.58GB / 7.47GB,  258MB/s
# New Data Upload               :  95%|█████████████▎| 4.78GB / 5.03GB,  237MB/s
#
# Processing Files (0 / 1)      :  89%|████████████▍ | 6.63GB / 7.47GB,  258MB/s
# New Data Upload               :  96%|█████████████▍| 4.84GB / 5.03GB,  237MB/s
#
# Processing Files (0 / 1)      :  89%|████████████▍ | 6.67GB / 7.47GB,  257MB/s
# New Data Upload               :  96%|█████████████▍| 4.87GB / 5.10GB,  235MB/s
#
# Processing Files (0 / 1)      :  90%|████████████▌ | 6.71GB / 7.47GB,  257MB/s
# New Data Upload               :  96%|█████████████▍| 4.91GB / 5.10GB,  236MB/s
#
# Processing Files (0 / 1)      :  90%|████████████▋ | 6.76GB / 7.47GB,  257MB/s
# New Data Upload               :  96%|█████████████▍| 4.96GB / 5.16GB,  236MB/s
#
# Processing Files (0 / 1)      :  91%|████████████▋ | 6.80GB / 7.47GB,  257MB/s
# New Data Upload               :  96%|█████████████▍| 5.00GB / 5.23GB,  236MB/s
#
# Processing Files (0 / 1)      :  92%|████████████▊ | 6.85GB / 7.47GB,  257MB/s
# New Data Upload               :  95%|█████████████▎| 5.05GB / 5.30GB,  236MB/s
#
# Processing Files (0 / 1)      :  92%|████████████▉ | 6.91GB / 7.47GB,  259MB/s
# New Data Upload               :  95%|█████████████▎| 5.11GB / 5.37GB,  237MB/s
#
# Processing Files (0 / 1)      :  93%|█████████████ | 6.96GB / 7.47GB,  259MB/s
# New Data Upload               :  96%|█████████████▍| 5.16GB / 5.37GB,  238MB/s
#
# Processing Files (0 / 1)      :  94%|█████████████▏| 7.02GB / 7.47GB,  261MB/s
# New Data Upload               :  96%|█████████████▍| 5.22GB / 5.43GB,  240MB/s
#
# Processing Files (0 / 1)      :  95%|█████████████▏| 7.06GB / 7.47GB,  261MB/s
# New Data Upload               :  96%|█████████████▍| 5.26GB / 5.50GB,  240MB/s
#
# Processing Files (0 / 1)      :  95%|█████████████▎| 7.10GB / 7.47GB,  254MB/s
# New Data Upload               :  95%|█████████████▎| 5.30GB / 5.57GB,  239MB/s
#
# Processing Files (0 / 1)      :  96%|█████████████▍| 7.15GB / 7.47GB,  248MB/s
# New Data Upload               :  95%|█████████████▎| 5.35GB / 5.63GB,  241MB/s
#
# Processing Files (0 / 1)      :  96%|█████████████▍| 7.20GB / 7.47GB,  244MB/s
# New Data Upload               :  95%|█████████████▎| 5.40GB / 5.67GB,  244MB/s
#
# Processing Files (0 / 1)      :  97%|█████████████▌| 7.25GB / 7.47GB,  246MB/s
# New Data Upload               :  96%|█████████████▍| 5.45GB / 5.67GB,  246MB/s
#
# Processing Files (0 / 1)      :  98%|█████████████▋| 7.32GB / 7.47GB,  250MB/s
# New Data Upload               :  97%|█████████████▌| 5.52GB / 5.67GB,  250MB/s
#
# Processing Files (0 / 1)      :  99%|█████████████▊| 7.38GB / 7.47GB,  253MB/s
# New Data Upload               :  98%|█████████████▊| 5.58GB / 5.67GB,  253MB/s
#
# Processing Files (0 / 1)      :  99%|█████████████▉| 7.42GB / 7.47GB,  253MB/s
# New Data Upload               :  99%|█████████████▊| 5.62GB / 5.67GB,  253MB/s
#
# Processing Files (0 / 1)      : 100%|█████████████▉| 7.44GB / 7.47GB,  249MB/s
# New Data Upload               :  99%|█████████████▉| 5.64GB / 5.67GB,  249MB/s
#
# Processing Files (0 / 1)      : 100%|█████████████▉| 7.45GB / 7.47GB,  246MB/s
# New Data Upload               : 100%|█████████████▉| 5.65GB / 5.67GB,  246MB/s
#
# Processing Files (0 / 1)      : 100%|█████████████▉| 7.46GB / 7.47GB,  241MB/s
# New Data Upload               : 100%|█████████████▉| 5.66GB / 5.67GB,  241MB/s
#
# Processing Files (0 / 1)      : 100%|█████████████▉| 7.46GB / 7.47GB,  238MB/s
# New Data Upload               : 100%|█████████████▉| 5.67GB / 5.67GB,  238MB/s
#
# Processing Files (0 / 1)      : 100%|█████████████▉| 7.47GB / 7.47GB,  233MB/s
# New Data Upload               : 100%|█████████████▉| 5.67GB / 5.67GB,  233MB/s
#
# Processing Files (0 / 1)      : 100%|█████████████▉| 7.47GB / 7.47GB,  228MB/s
# New Data Upload               : 100%|█████████████▉| 5.67GB / 5.67GB,  228MB/s
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|█████████████▉| 7.47GB / 7.47GB
#
# Processing Files (1 / 1)      : 100%|██████████████| 7.47GB / 7.47GB,  193MB/s
# New Data Upload               : 100%|██████████████| 5.67GB / 5.67GB,  193MB/s
#
#   ...nt-pi05/model.safetensors: 100%|██████████████| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|██████████████| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|██████████████| 7.47GB / 7.47GB
#
#   ...nt-pi05/model.safetensors: 100%|██████████████| 7.47GB / 7.47GB
#
# Processing Files (1 / 1)      : 100%|██████████████| 7.47GB / 7.47GB,  171MB/s
# New Data Upload               : 100%|██████████████| 5.67GB / 5.67GB,  171MB/s
#   ...nt-pi05/model.safetensors: 100%|██████████████| 7.47GB / 7.47GB
# INFO 2026-04-02 20:27:03 etrained.py:245 Model pushed to https://huggingface.co/gimarchetti/clr-experiment-pi05
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...zer_processor.safetensors: 100%|██████████████| 12.9kB / 12.9kB
#
# Processing Files (1 / 1)      : 100%|██████████████| 12.9kB / 12.9kB,   ???B/s
#
#   ...zer_processor.safetensors: 100%|██████████████| 12.9kB / 12.9kB
#
#   ...zer_processor.safetensors: 100%|██████████████| 12.9kB / 12.9kB
#
#   ...zer_processor.safetensors: 100%|██████████████| 12.9kB / 12.9kB
#
#   ...zer_processor.safetensors: 100%|██████████████| 12.9kB / 12.9kB
#
# Processing Files (1 / 1)      : 100%|██████████████| 12.9kB / 12.9kB,  0.00B/s
# New Data Upload               : |                  |  0.00B /  0.00B,  0.00B/s
#   ...zer_processor.safetensors: 100%|██████████████| 12.9kB / 12.9kB
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING 2026-04-02 20:27:04 /hf_api.py:4298 No files have been modified since last commit. Skipping to prevent empty commit.
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...zer_processor.safetensors: 100%|██████████████| 12.9kB / 12.9kB
#
# Processing Files (1 / 1)      : 100%|██████████████| 12.9kB / 12.9kB,   ???B/s
#
#   ...zer_processor.safetensors: 100%|██████████████| 12.9kB / 12.9kB
#
# Processing Files (1 / 1)      : 100%|██████████████| 12.9kB / 12.9kB,  0.00B/s
# New Data Upload               : |                  |  0.00B /  0.00B,  0.00B/s
#   ...zer_processor.safetensors: 100%|██████████████| 12.9kB / 12.9kB
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING 2026-04-02 20:27:05 /hf_api.py:4298 No files have been modified since last commit. Skipping to prevent empty commit.

# %% [markdown]
# ## Train GR00T N 1.5 TO BE DONE YET

# %%
# !pip install ninja "packaging>=24.2,<26.0"
# !pip install peft
# !pip install dm-tree==0.1.9
# !pip install -U transformers
# !pip install flash-attn==2.7.3 --no-build-isolation

# %%
# !lerobot-train\
    --dataset.repo_id=Jeongeun/tutorial_v2 \
    --dataset.root=dataset/leader_data \
    --policy.type=groot \
    --policy.repo_id=={YOUR REPO} \
    --output_dir=ckpt/tutorial_v2_groot \
    --job_name=tutorial_v2_groot \
    --wandb.enable=false \
    --steps=20000 \
    --policy.chunk_size=20 \
    --policy.n_action_steps=20 \
    --batch_size=32
