# %% [markdown]
# ## Train pi0.5

# %%
# !pip uninstall -y transformers
# !pip install git+https://github.com/huggingface/transformers.git@fix/lerobot_openpi

# %%
# !lerobot-train\
    --dataset.repo_id=Jeongeun/tutorial_v2 \
    --dataset.root=dataset/leader_data \
    --policy.type=pi05 \
    --policy.push_to_hub=true \
    --policy.repo_id=gimarchetti/mujoco_pi05 \
    --output_dir=./ckpt/tutorial_v2_pi05 \
    --job_name=tutorial_v2_pi05 \
    --policy.pretrained_path=lerobot/pi05_base \
    --policy.compile_model=false \
    --policy.gradient_checkpointing=true \
    --wandb.enable=false \
    --policy.dtype=bfloat16 \
    --policy.freeze_vision_encoder=false \
    --policy.train_expert_only=false \
    --steps=10000 \
    --log_freq=50 \
    --eval_freq=-1 \
    --policy.device=cuda \
    --policy.chunk_size=20 \
    --policy.n_action_steps=20 \
    --batch_size=32
# Out:
# INFO 2026-02-17 06:54:50 ot_train.py:274 {'batch_size': 32,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'Jeongeun/tutorial_v2',
#              'revision': None,
#              'root': 'dataset/leader_data',
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': -1,
#  'job_name': 'tutorial_v2_pi05',
#  'log_freq': 50,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.95],
#                'eps': 1e-08,
#                'grad_clip_norm': 1.0,
#                'lr': 2.5e-05,
#                'type': 'adamw',
#                'weight_decay': 0.01},
#  'output_dir': 'ckpt/tutorial_v2_pi05',
#  'peft': None,
#  'policy': {'action_expert_variant': 'gemma_300m',
#             'chunk_size': 20,
#             'compile_mode': 'max-autotune',
#             'compile_model': False,
#             'device': 'cuda',
#             'dtype': 'bfloat16',
#             'empty_cameras': 0,
#             'freeze_vision_encoder': False,
#             'gradient_checkpointing': True,
#             'image_resolution': [224, 224],
#             'input_features': {},
#             'license': None,
#             'max_action_dim': 32,
#             'max_period': 4.0,
#             'max_state_dim': 32,
#             'min_period': 0.004,
#             'n_action_steps': 20,
#             'n_obs_steps': 1,
#             'normalization_mapping': {'ACTION': <NormalizationMode.QUANTILES: 'QUANTILES'>,
#                                       'STATE': <NormalizationMode.QUANTILES: 'QUANTILES'>,
#                                       'VISUAL': <NormalizationMode.IDENTITY: 'IDENTITY'>},
#             'num_inference_steps': 10,
#             'optimizer_betas': [0.9, 0.95],
#             'optimizer_eps': 1e-08,
#             'optimizer_grad_clip_norm': 1.0,
#             'optimizer_lr': 2.5e-05,
#             'optimizer_weight_decay': 0.01,
#             'output_features': {},
#             'paligemma_variant': 'gemma_2b',
#             'pretrained_path': 'lerobot/pi05_base',
#             'private': None,
#             'push_to_hub': True,
#             'repo_id': 'gimarchetti/mujoco_pi05',
#             'rtc_config': None,
#             'scheduler_decay_lr': 2.5e-06,
#             'scheduler_decay_steps': 30000,
#             'scheduler_warmup_steps': 1000,
#             'tags': None,
#             'time_sampling_beta_alpha': 1.5,
#             'time_sampling_beta_beta': 1.0,
#             'time_sampling_offset': 0.001,
#             'time_sampling_scale': 0.999,
#             'tokenizer_max_length': 200,
#             'train_expert_only': False,
#             'type': 'pi05',
#             'use_amp': False,
#             'use_peft': False},
#  'rabc_epsilon': 1e-06,
#  'rabc_head_mode': 'sparse',
#  'rabc_kappa': 0.01,
#  'rabc_progress_path': None,
#  'rename_map': {},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 20000,
#  'scheduler': {'decay_lr': 2.5e-06,
#                'num_decay_steps': 30000,
#                'num_warmup_steps': 1000,
#                'peak_lr': 2.5e-05,
#                'type': 'cosine_decay_with_warmup'},
#  'seed': 1000,
#  'steps': 10000,
#  'tolerance_s': 0.0001,
#  'use_policy_training_preset': True,
#  'use_rabc': False,
#  'wandb': {'disable_artifact': False,
#            'enable': False,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# INFO 2026-02-17 06:54:50 ot_train.py:282 Logs will be saved locally.
# INFO 2026-02-17 06:54:50 ot_train.py:294 Creating dataset
# INFO 2026-02-17 06:54:50 ot_train.py:313 Creating policy
# The PI05 model is a direct port of the OpenPI implementation.
# This implementation follows the original OpenPI structure for compatibility.
# Original implementation: https://github.com/Physical-Intelligence/openpi
# INFO 2026-02-17 06:56:02 ing_pi05.py:592 Enabled gradient checkpointing for PI05Pytorch model
# Loading model from: lerobot/pi05_base
# ✓ Loaded state dict from model.safetensors
# WARNING 2026-02-17 06:56:05 ng_pi05.py:1099 Vision embedding key might need handling: paligemma_with_expert.paligemma.model.vision_tower.vision_model.embeddings.patch_embedding.bias
# WARNING 2026-02-17 06:56:05 ng_pi05.py:1099 Vision embedding key might need handling: paligemma_with_expert.paligemma.model.vision_tower.vision_model.embeddings.patch_embedding.weight
# Remapped: action_in_proj.bias -> model.action_in_proj.bias
# Remapped: action_in_proj.weight -> model.action_in_proj.weight
# Remapped: action_out_proj.bias -> model.action_out_proj.bias
# Remapped: action_out_proj.weight -> model.action_out_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.lm_head.weight -> model.paligemma_with_expert.gemma_expert.lm_head.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.bias
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.input_layernorm.dense.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.down_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.gate_proj.weight
# Remapped: paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight -> model.paligemma_with_expert.gemma_expert.model.layers.0.mlp.up_proj.weight
# Remapped 812 state dict keys
# Warning: Could not remap state dict keys: Error(s) in loading state_dict for PI05Policy:
# 	Missing key(s) in state_dict: "model.paligemma_with_expert.paligemma.model.language_model.embed_tokens.weight".
# INFO 2026-02-17 06:56:10 ot_train.py:366 Creating optimizer and scheduler
# INFO 2026-02-17 06:56:10 hedulers.py:105 Auto-scaling LR scheduler: num_training_steps (10000) < num_decay_steps (30000). Scaling warmup: 1000 → 333, decay: 30000 → 10000 (scale factor: 0.333)
# INFO 2026-02-17 06:56:10 ot_train.py:401 Output dir: ckpt/tutorial_v2_pi05
# INFO 2026-02-17 06:56:10 ot_train.py:408 cfg.steps=10000 (10K)
# INFO 2026-02-17 06:56:10 ot_train.py:409 dataset.num_frames=9758 (10K)
# INFO 2026-02-17 06:56:10 ot_train.py:410 dataset.num_episodes=50
# INFO 2026-02-17 06:56:10 ot_train.py:413 Effective batch size: 32 x 1 = 32
# INFO 2026-02-17 06:56:10 ot_train.py:414 num_learnable_params=3616757520 (4B)
# INFO 2026-02-17 06:56:10 ot_train.py:415 num_total_params=3616757520 (4B)
# INFO 2026-02-17 06:56:10 ot_train.py:471 Start offline training on a fixed dataset, with effective batch size: 32
# INFO 2026-02-17 06:59:07 ot_train.py:501 step:50 smpl:2K ep:8 epch:0.16 loss:0.547 grdn:6.456 lr:2.0e-06 updt_s:3.485 data_s:0.037
# INFO 2026-02-17 07:02:00 ot_train.py:501 step:100 smpl:3K ep:16 epch:0.33 loss:0.323 grdn:2.257 lr:5.7e-06 updt_s:3.454 data_s:0.012
# INFO 2026-02-17 07:04:54 ot_train.py:501 step:150 smpl:5K ep:25 epch:0.49 loss:0.204 grdn:1.639 lr:9.5e-06 updt_s:3.456 data_s:0.012
# INFO 2026-02-17 07:07:47 ot_train.py:501 step:200 smpl:6K ep:33 epch:0.66 loss:0.136 grdn:1.543 lr:1.3e-05 updt_s:3.456 data_s:0.012
# INFO 2026-02-17 07:10:41 ot_train.py:501 step:250 smpl:8K ep:41 epch:0.82 loss:0.111 grdn:1.528 lr:1.7e-05 updt_s:3.457 data_s:0.012
# INFO 2026-02-17 07:13:34 ot_train.py:501 step:300 smpl:10K ep:49 epch:0.98 loss:0.097 grdn:1.489 lr:2.1e-05 updt_s:3.456 data_s:0.012
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# INFO 2026-02-17 14:19:22 ot_train.py:501 step:8K smpl:245K ep:1K epch:25.09 loss:0.011 grdn:0.518 lr:5.5e-06 updt_s:3.457 data_s:0.032
# INFO 2026-02-17 14:22:16 ot_train.py:501 step:8K smpl:246K ep:1K epch:25.25 loss:0.011 grdn:0.492 lr:5.4e-06 updt_s:3.463 data_s:0.012
# INFO 2026-02-17 14:25:10 ot_train.py:501 step:8K smpl:248K ep:1K epch:25.42 loss:0.010 grdn:0.503 lr:5.3e-06 updt_s:3.462 data_s:0.012
# INFO 2026-02-17 14:28:04 ot_train.py:501 step:8K smpl:250K ep:1K epch:25.58 loss:0.011 grdn:0.511 lr:5.1e-06 updt_s:3.462 data_s:0.012
# INFO 2026-02-17 14:30:58 ot_train.py:501 step:8K smpl:251K ep:1K epch:25.74 loss:0.010 grdn:0.496 lr:5.0e-06 updt_s:3.462 data_s:0.012
# INFO 2026-02-17 14:33:51 ot_train.py:501 step:8K smpl:253K ep:1K epch:25.91 loss:0.009 grdn:0.490 lr:4.9e-06 updt_s:3.462 data_s:0.012
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# INFO 2026-02-17 14:36:47 ot_train.py:501 step:8K smpl:254K ep:1K epch:26.07 loss:0.010 grdn:0.490 lr:4.8e-06 updt_s:3.466 data_s:0.032
# INFO 2026-02-17 14:39:41 ot_train.py:501 step:8K smpl:256K ep:1K epch:26.23 loss:0.009 grdn:0.482 lr:4.7e-06 updt_s:3.474 data_s:0.012
# INFO 2026-02-17 14:42:36 ot_train.py:501 step:8K smpl:258K ep:1K epch:26.40 loss:0.011 grdn:0.496 lr:4.6e-06 updt_s:3.478 data_s:0.012
# INFO 2026-02-17 14:45:30 ot_train.py:501 step:8K smpl:259K ep:1K epch:26.56 loss:0.010 grdn:0.488 lr:4.5e-06 updt_s:3.474 data_s:0.012
# INFO 2026-02-17 14:48:25 ot_train.py:501 step:8K smpl:261K ep:1K epch:26.73 loss:0.011 grdn:0.497 lr:4.4e-06 updt_s:3.475 data_s:0.012
# INFO 2026-02-17 14:51:19 ot_train.py:501 step:8K smpl:262K ep:1K epch:26.89 loss:0.011 grdn:0.523 lr:4.3e-06 updt_s:3.476 data_s:0.012
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# INFO 2026-02-17 14:54:14 ot_train.py:501 step:8K smpl:264K ep:1K epch:27.05 loss:0.009 grdn:0.495 lr:4.2e-06 updt_s:3.464 data_s:0.033
# INFO 2026-02-17 14:57:08 ot_train.py:501 step:8K smpl:266K ep:1K epch:27.22 loss:0.010 grdn:0.480 lr:4.1e-06 updt_s:3.453 data_s:0.012

# %% [markdown]
# ## Train GR00T N 1.5

# %%
# !pip install ninja "packaging>=24.2,<26.0"
# !pip install peft
# !pip install dm-tree==0.1.9
# !pip install -U transformers
# !pip install flash-attn==2.7.3 --no-build-isolation

# %%
# !lerobot-train\
    --dataset.repo_id=Jeongeun/tutorial_v2 \
    --dataset.root=dataset/leader_data \
    --policy.type=groot \
    --policy.repo_id=={YOUR REPO} \
    --output_dir=ckpt/tutorial_v2_groot \
    --job_name=tutorial_v2_groot \
    --wandb.enable=false \
    --steps=20000 \
    --policy.chunk_size=20 \
    --policy.n_action_steps=20 \
    --batch_size=32
