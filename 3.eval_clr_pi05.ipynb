# %%
#!pip uninstall -y transformers
#!pip install git+https://github.com/huggingface/transformers.git@fix/lerobot_openpi

# %%
from datetime import datetime
import random
import numpy as np
import os
import torch
import json
from PIL import Image
from src.env.env import RILAB_OMY_ENV
from torchvision import transforms

from lerobot.policies.pi05.modeling_pi05 import PI05Policy
from lerobot.processor import PolicyAction, PolicyProcessorPipeline
from lerobot.processor.converters import (
    batch_to_transition,
    policy_action_to_transition,
    transition_to_batch,
    transition_to_policy_action,
)
from lerobot.utils.constants import POLICY_POSTPROCESSOR_DEFAULT_NAME, POLICY_PREPROCESSOR_DEFAULT_NAME

import glfw
# Out:
# /mnt/content/Lerobot-MujoCo/src/mujoco_helper/transforms.py:126: SyntaxWarning: invalid escape sequence '\o'
#   R to \omega
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 8
#       6 import json
#       7 from PIL import Image
# ----> 8 from src.env.env import RILAB_OMY_ENV
#       9 from torchvision import transforms
#      11 from lerobot.policies.pi05.modeling_pi05 import PI05Policy
#
# File /mnt/content/Lerobot-MujoCo/src/env/env.py:5
#       3 import numpy as np
#       4 import xml.etree.ElementTree as ET
# ----> 5 from src.mujoco_helper import MuJoCoParserClass
#       6 from src.object_helpers import ObjectSpawner
#       7 from src.mujoco_helper.utils import prettify, sample_xyzs, rotation_matrix
#
# File /mnt/content/Lerobot-MujoCo/src/mujoco_helper/__init__.py:1
# ----> 1 from .mujoco_parser import MuJoCoParserClass
#
# File /mnt/content/Lerobot-MujoCo/src/mujoco_helper/mujoco_parser.py:24
#      11 MUJOCO_VERSION = tuple(map(int,mujoco.__version__.split('.')))
#      13 from .transforms import (
#      14     t2p,
#      15     t2r,
#    (...)     22     get_rotation_matrix_from_two_points,
#      23 )
# ---> 24 from .utils import (
#      25     trim_scale,
#      26     compute_view_params,
#      27     get_idxs,
#      28     get_colors,
#      29     get_monitor_size,
#      30     TicTocClass,
#      31 )
#      33 class MinimalCallbacks:
#      34     def __init__(self, hide_menus):
#
# File /mnt/content/Lerobot-MujoCo/src/mujoco_helper/utils.py:2
#       1 import os
# ----> 2 import pyautogui
#       3 import sys
#       4 import time
#
# File ~/miniconda3/envs/mujoco2/lib/python3.12/site-packages/pyautogui/__init__.py:246
#     242     screenshot = _couldNotImportPyScreeze
#     245 try:
# --> 246     import mouseinfo
#     248     def mouseInfo():
#     249         """
#     250         Launches the MouseInfo app. This application provides mouse coordinate information which can be useful when
#     251         planning GUI automation tasks. This function blocks until the application is closed.
#     252         """
#
# File ~/miniconda3/envs/mujoco2/lib/python3.12/site-packages/mouseinfo/__init__.py:223
#     220     else:
#     221         raise
# --> 223 _display = Display(os.environ['DISPLAY'])
#     225 def _linuxPosition():
#     226     coord = _display.screen().root.query_pointer()._data
#
# File <frozen os>:714, in __getitem__(self, key)
#
# KeyError: 'DISPLAY'

# %%
import configparser
config = configparser.ConfigParser()
config.read("experiment.cfg")
exp = config["experiment"]

DATASET_ROOT = exp["DATASET_ROOT"]
DATASET_REPO = exp["DATASET_REPO"]
POLICY_REPO = exp["POLICY_REPO"]
OUTPUT_DIR = exp["OUTPUT_DIR"]
JOB_NAME = exp["JOB_NAME"] + datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
MAX_TRAIN_STEPS = int(exp["MAX_TRAIN_STEPS"])
CHUNK_SIZE = int(exp["CHUNK_SIZE"])
ACTION_STEPS = int(exp["ACTION_STEPS"])
BATCH_SIZE = int(exp["BATCH_SIZE"])

# %%
'''
Load environment configuration and initialize environments
'''
# Evaluation Configuration
TEST_EPISODES = 3 #@param {"type":"integer"}
MAX_EPISODE_STEPS = 50_000 #@param {"type":"string"}
TASK="Put the red cube in the open drawer then close the drawer"

# %% [markdown]
# ## Load Model

# %%
'''
Meta data is for loading dataset statistics and feature information
'''
#repo_id_or_path = 'Jeongeun/tutorial_v2_pi05' # Use this for loading pretrained model from the hub
device = 'mps' if torch.backends.mps.is_available() else 'cuda' if torch.cuda.is_available() else 'cpu'

policy = PI05Policy.from_pretrained(POLICY_REPO)
_ = policy.to(device)
# Out:
# The PI05 model is a direct port of the OpenPI implementation.
# This implementation follows the original OpenPI structure for compatibility.
# Original implementation: https://github.com/Physical-Intelligence/openpi
# WARNING:lerobot.configs.policies:Device 'cuda' is not available. Switching to 'mps'.
# WARNING:lerobot.configs.policies:Device 'cuda' is not available. Switching to 'mps'.
# Loading model from: gimarchetti/ur5-experiment-pi05
# WARNING:root:Vision embedding key might need handling: model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.embeddings.patch_embedding.bias
# WARNING:root:Vision embedding key might need handling: model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.embeddings.patch_embedding.weight
# ✓ Loaded state dict from model.safetensors
# Warning: Could not remap state dict keys: Error(s) in loading state_dict for PI05Policy:
# 	Missing key(s) in state_dict: "model.paligemma_with_expert.paligemma.model.language_model.embed_tokens.weight".

# %% [markdown]
# **Note**: If you want to change number of actions in chunk to be executed, please change:
#
# ```policy.config.n_action_steps = YOUR_DESIRED_NUMBER```

# %%
# Set the number of action steps to run in the environment for one invocation of the policy
policy.config.n_action_steps = 10

# %%
# Check normalization stats dimension
preprocessor = PolicyProcessorPipeline.from_pretrained(
                pretrained_model_name_or_path=POLICY_REPO,
                config_filename= f"{POLICY_PREPROCESSOR_DEFAULT_NAME}.json",
                overrides={"device_processor": {"device": device}},
                to_transition=batch_to_transition,
                to_output=transition_to_batch,
            )

for step in preprocessor.steps:
    if hasattr(step, "stats"):
        if "observation.state" in step.stats:
            print(f"Stats dimension for observation.state: {step.stats['observation.state']['mean'].shape}")

postprocessor = PolicyProcessorPipeline.from_pretrained(
                pretrained_model_name_or_path=POLICY_REPO,
                config_filename= f"{POLICY_POSTPROCESSOR_DEFAULT_NAME}.json",
                overrides={"device_processor": {"device": device}},
                to_transition=policy_action_to_transition,
                to_output=transition_to_policy_action,
            )
# Out:
# Stats dimension for observation.state: (7,)

# %%
batch = {
    'observation.state': np.zeros((1, 7), dtype=np.float32),
    'observation.image': np.zeros((1, 3, 256, 256), dtype=np.float32),
    'observation.wrist_image': np.zeros((1, 3, 256, 256), dtype=np.float32),
    'task': [TASK]
}
batch = preprocessor(batch)  # to initialize the processors
_ = policy.select_action(batch)  # to initialize the model

# %% [markdown]
# ## Load Environment

# %%
config_file_path = './configs/train_ur5.json'
with open(config_file_path) as f:
    env_conf = json.load(f)
omy_env = RILAB_OMY_ENV(cfg=env_conf, seed=0, 
                        action_type='joint', 
                        obs_type='joint_pos',
                        vis_mode = 'teleop')
# Out:
# -----------------------------------------------------------------------------
# name:[tabletop_env] dt:[0.002] HZ:[500]
#  n_qpos:[38] n_qvel:[35] n_qacc:[35] n_ctrl:[8]
#  integrator:[RK4]
#
# n_body:[36]
#  [0/36] [world] mass:[0.00]kg
#  [1/36] [front_object_table] mass:[1.00]kg
#  [2/36] [camera] mass:[0.00]kg
#  [3/36] [camera2] mass:[0.00]kg
#  [4/36] [camera3] mass:[0.00]kg
#  [5/36] [base] mass:[4.00]kg
#  [6/36] [shoulder_link] mass:[3.70]kg
#  [7/36] [upper_arm_link] mass:[8.39]kg
#  [8/36] [forearm_link] mass:[2.27]kg
#  [9/36] [wrist_1_link] mass:[1.22]kg
#  [10/36] [wrist_2_link] mass:[1.22]kg
#  [11/36] [wrist_3_link] mass:[0.19]kg
#  [12/36] [attachment] mass:[0.00]kg
#  [13/36] [base_mount] mass:[0.15]kg
#  [14/36] [gripper_base] mass:[0.78]kg
#  [15/36] [tcp_link] mass:[0.00]kg
#  [16/36] [camera_center] mass:[0.00]kg
#  [17/36] [right_driver] mass:[0.01]kg
#  [18/36] [right_coupler] mass:[0.01]kg
#  [19/36] [right_spring_link] mass:[0.02]kg
#  [20/36] [right_follower] mass:[0.01]kg
#  [21/36] [right_pad] mass:[0.00]kg
#  [22/36] [right_silicone_pad] mass:[0.00]kg
#  [23/36] [left_driver] mass:[0.01]kg
#  [24/36] [left_coupler] mass:[0.01]kg
#  [25/36] [left_spring_link] mass:[0.02]kg
#  [26/36] [left_follower] mass:[0.01]kg
#  [27/36] [left_pad] mass:[0.00]kg
#  [28/36] [left_silicone_pad] mass:[0.00]kg
#  [29/36] [body_obj_wooden_cabinet] mass:[2.24]kg
#  [30/36] [body_obj_wooden_cabinet_top] mass:[3.00]kg
#  [31/36] [body_obj_wooden_cabinet_middle] mass:[3.00]kg
#  [32/36] [body_obj_wooden_cabinet_bottom] mass:[3.00]kg
#  [33/36] [body_obj_box_1] mass:[1.00]kg
#  [34/36] [body_obj_cylinder_1] mass:[1.00]kg
#  [35/36] [body_obj_cylinder_2] mass:[1.00]kg
# body_total_mass:[37.29]kg
#
# n_geom:[108]
# geom_names:['floor', 'front_object_table', 'front_object_top', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'right_pad1', 'right_pad2', None, None, None, None, None, None, None, None, None, None, 'left_pad1', 'left_pad2', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'box_1_geom', 'cylinder_1_geom', 'cylinder_2_geom']
#
# n_mesh:[35]
# mesh_names:['base_0', 'base_1', 'shoulder_0', 'shoulder_1', 'shoulder_2', 'upperarm_0', 'upperarm_1', 'upperarm_2', 'upperarm_3', 'forearm_0', 'forearm_1', 'forearm_2', 'forearm_3', 'wrist1_0', 'wrist1_1', 'wrist1_2', 'wrist2_0', 'wrist2_1', 'wrist2_2', 'wrist3', 'base_mount', 'base', 'driver', 'coupler', 'follower', 'pad', 'silicone_pad', 'spring_link', 'wooden_cabinet_top_vis', 'wooden_cabinet_base_vis', 'wooden_cabinet_top_handle_vis', 'wooden_cabinet_middle_vis', 'wooden_cabinet_middle_handle_vis', 'wooden_cabinet_bottom_vis', 'wooden_cabinet_bottom_handle_vis']
#
# n_joint:[20]
#  [0/20] [joint1] axis:[0. 0. 1.]
#  [1/20] [joint2] axis:[0. 1. 0.]
#  [2/20] [joint3] axis:[0. 1. 0.]
#  [3/20] [joint4] axis:[0. 1. 0.]
#  [4/20] [joint5] axis:[0. 0. 1.]
#  [5/20] [joint6] axis:[0. 1. 0.]
#  [6/20] [rh_r1] axis:[1. 0. 0.]
#  [7/20] [right_coupler_joint] axis:[1. 0. 0.]
#  [8/20] [right_spring_link_joint] axis:[1. 0. 0.]
#  [9/20] [rh_r2] axis:[1. 0. 0.]
#  [10/20] [rh_l1] axis:[1. 0. 0.]
#  [11/20] [left_coupler_joint] axis:[1. 0. 0.]
#  [12/20] [left_spring_link_joint] axis:[1. 0. 0.]
#  [13/20] [rh_l2] axis:[1. 0. 0.]
#  [14/20] [wooden_cabinet_top_level] axis:[0. 1. 0.]
#  [15/20] [wooden_cabinet_middle_level] axis:[0. 1. 0.]
#  [16/20] [wooden_cabinet_bottom_level] axis:[0. 1. 0.]
#  [17/20] [None] axis:[0. 0. 1.]
#  [18/20] [None] axis:[0. 0. 1.]
#  [19/20] [None] axis:[0. 0. 1.]
#
# n_dof:[35] (=number of rows of Jacobian)
#  [0/35] [None] attached joint:[joint1] body:[shoulder_link]
#  [1/35] [None] attached joint:[joint2] body:[upper_arm_link]
#  [2/35] [None] attached joint:[joint3] body:[forearm_link]
#  [3/35] [None] attached joint:[joint4] body:[wrist_1_link]
#  [4/35] [None] attached joint:[joint5] body:[wrist_2_link]
#  [5/35] [None] attached joint:[joint6] body:[wrist_3_link]
#  [6/35] [None] attached joint:[rh_r1] body:[right_driver]
#  [7/35] [None] attached joint:[right_coupler_joint] body:[right_coupler]
#  [8/35] [None] attached joint:[right_spring_link_joint] body:[right_spring_link]
#  [9/35] [None] attached joint:[rh_r2] body:[right_follower]
#  [10/35] [None] attached joint:[rh_l1] body:[left_driver]
#  [11/35] [None] attached joint:[left_coupler_joint] body:[left_coupler]
#  [12/35] [None] attached joint:[left_spring_link_joint] body:[left_spring_link]
#  [13/35] [None] attached joint:[rh_l2] body:[left_follower]
#  [14/35] [None] attached joint:[wooden_cabinet_top_level] body:[body_obj_wooden_cabinet_top]
#  [15/35] [None] attached joint:[wooden_cabinet_middle_level] body:[body_obj_wooden_cabinet_middle]
#  [16/35] [None] attached joint:[wooden_cabinet_bottom_level] body:[body_obj_wooden_cabinet_bottom]
#  [17/35] [None] attached joint:[None] body:[body_obj_box_1]
#  [18/35] [None] attached joint:[None] body:[body_obj_box_1]
#  [19/35] [None] attached joint:[None] body:[body_obj_box_1]
#  [20/35] [None] attached joint:[None] body:[body_obj_box_1]
#  [21/35] [None] attached joint:[None] body:[body_obj_box_1]
#  [22/35] [None] attached joint:[None] body:[body_obj_box_1]
#  [23/35] [None] attached joint:[None] body:[body_obj_cylinder_1]
#  [24/35] [None] attached joint:[None] body:[body_obj_cylinder_1]
#  [25/35] [None] attached joint:[None] body:[body_obj_cylinder_1]
#  [26/35] [None] attached joint:[None] body:[body_obj_cylinder_1]
#  [27/35] [None] attached joint:[None] body:[body_obj_cylinder_1]
#  [28/35] [None] attached joint:[None] body:[body_obj_cylinder_1]
#  [29/35] [None] attached joint:[None] body:[body_obj_cylinder_2]
#  [30/35] [None] attached joint:[None] body:[body_obj_cylinder_2]
#  [31/35] [None] attached joint:[None] body:[body_obj_cylinder_2]
#  [32/35] [None] attached joint:[None] body:[body_obj_cylinder_2]
#  [33/35] [None] attached joint:[None] body:[body_obj_cylinder_2]
#  [34/35] [None] attached joint:[None] body:[body_obj_cylinder_2]
#
# Free joint information. n_free_joint:[3]
#  [0/3] [None] body_name_attached:[body_obj_box_1]
#  [1/3] [None] body_name_attached:[body_obj_cylinder_1]
#  [2/3] [None] body_name_attached:[body_obj_cylinder_2]
#
# Revolute joint information. n_rev_joint:[14]
#  [0/14] [joint1] range:[-6.283]~[6.283]
#  [1/14] [joint2] range:[-6.283]~[6.283]
#  [2/14] [joint3] range:[-3.142]~[3.142]
#  [3/14] [joint4] range:[-6.283]~[6.283]
#  [4/14] [joint5] range:[-6.283]~[6.283]
#  [5/14] [joint6] range:[-6.283]~[6.283]
#  [6/14] [rh_r1] range:[0.000]~[0.800]
#  [7/14] [right_coupler_joint] range:[-1.570]~[0.000]
#  [8/14] [right_spring_link_joint] range:[-0.297]~[0.800]
#  [9/14] [rh_r2] range:[-0.873]~[0.873]
#  [10/14] [rh_l1] range:[0.000]~[0.800]
#  [11/14] [left_coupler_joint] range:[-1.570]~[0.000]
#  [12/14] [left_spring_link_joint] range:[-0.297]~[0.800]
#  [13/14] [rh_l2] range:[-0.873]~[0.873]
#
# Prismatic joint information. n_pri_joint:[3]
#  [0/3] [wooden_cabinet_top_level] range:[-0.160]~[0.010]
#  [1/3] [wooden_cabinet_middle_level] range:[-0.160]~[0.010]
#  [2/3] [wooden_cabinet_bottom_level] range:[-0.160]~[0.010]
#
# Control information. n_ctrl:[8]
#  [0/8] [actuator_joint1] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [1/8] [actuator_joint2] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [2/8] [actuator_joint3] range:[-3.142]~[3.142] gear:[1.00] type:[JOINT]
#  [3/8] [actuator_joint4] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [4/8] [actuator_joint5] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [5/8] [actuator_joint6] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [6/8] [actuator_rh_r1] range:[0.000]~[0.800] gear:[1.00] type:[JOINT]
#  [7/8] [actuator_rh_l1] range:[0.000]~[0.800] gear:[1.00] type:[JOINT]
#
# Camera information. n_cam:[4]
#  [0/4] [agentview] fov:[60.0]
#  [1/4] [topview] fov:[60.0]
#  [2/4] [sideview] fov:[60.0]
#  [3/4] [egocentric] fov:[90.0]
#
# n_sensor:[0]
# sensor_names:[]
# n_site:[24]
# site_names:['joint1', 'joint2', 'joint3', 'joint4', 'joint5', 'joint6', 'attachment_site', 'pinch', 'top_side', 'bottom_site', 'top_site_wooden_cabinet', 'horizontal_radius_site', 'top_region_wooden_cabinet', 'middle_region_wooden_cabinet', 'bottom_region_wooden_cabinet', 'top_site_box_1', 'bottom_site_box_1', 'horizontal_radius_site_box_1', 'top_site_cylinder_1', 'bottom_site_cylinder_1', 'horizontal_radius_site_cylinder_1', 'top_site_cylinder_2', 'bottom_site_cylinder_2', 'horizontal_radius_site_cylinder_2']
# -----------------------------------------------------------------------------
# env:[tabletop_env] reset
# wooden_cabinet
# box_1
# cylinder_1
# cylinder_2
# env:[tabletop_env] reset
# env:[tabletop_env] initalize viewer
# ['top', 'open']
# DONE INITIALIZATION

# %%
def get_default_transform():
    """
    Returns a torchvision transform that:
     Converts to a FloatTensor and scales pixel values [0,255] -> [0.0,1.0]
    """
    return transforms.Compose([
        transforms.ToTensor(),  # PIL [0–255] -> FloatTensor [0.0–1.0], shape C×H×W
    ])
IMG_TRANSFORM = get_default_transform()

# %% [markdown]
# ## Evaluate

# %%
'''
Run one evaluation episode
'''
def run_one_episode():
    omy_env.reset()
    policy.reset()
    observation = omy_env.get_observation()
    omy_env.env.tick = 0
    success = False
    while omy_env.env.is_viewer_alive() and omy_env.env.tick < MAX_EPISODE_STEPS:
        omy_env.step_env()
        if omy_env.env.loop_every(HZ = 20):
            success = omy_env.check_success()
            if success: break
            if omy_env.env.is_key_pressed_once(glfw.KEY_Z):
                break  # for debugging: press 'z' to end the episode
            agent_image, wrist_image = omy_env.grab_image(return_side=False)
            # # resize to 256x256
            frame = {
                "observation.state": observation[:7].astype(np.float32),
                'task': [TASK] #[env_conf['language_instruction']]
            }
            agent_image = Image.fromarray(agent_image)
            wrist_image = Image.fromarray(wrist_image)
            agent_image = agent_image.resize((256, 256))
            wrist_image = wrist_image.resize((256, 256))
            agent_image = IMG_TRANSFORM(agent_image)
            wrist_image = IMG_TRANSFORM(wrist_image)
            frame["observation.image"] = agent_image
            frame["observation.wrist_image"] = wrist_image
            # numpy to torch
            frame = {k: torch.tensor(v, dtype=torch.float32).unsqueeze(0) if isinstance(v, np.ndarray) else v for k, v in frame.items()}
            # pre-process the frame
            frame = preprocessor(frame)
            # select action
            action = policy.select_action(frame)
            # post-process the action
            action = postprocessor(action)
            action = action.squeeze(0).cpu().numpy()
            observation = omy_env.step(action, gripper_mode='continuous')
            omy_env.render()
    return success

# %%
'''
Run evaluation over multiple episodes
'''
results = []
for episode in range(TEST_EPISODES):
    success = run_one_episode()
    results.append(success)
    print(f"Episode {episode+1}/{TEST_EPISODES} - Success: {success}")
omy_env.env.close_viewer()
# log average success rate
avg_success = sum(results) / len(results)
print(f"Average Success Rate over {TEST_EPISODES} episodes: {avg_success*100:.2f}%")
# Out:
# ['top', 'open']
# DONE INITIALIZATION
# Episode 1/3 - Success: False
# ['top', 'open']
# DONE INITIALIZATION
# Episode 2/3 - Success: False
# ['top', 'open']
# DONE INITIALIZATION
# Episode 3/3 - Success: False
# Average Success Rate over 3 episodes: 0.00%
